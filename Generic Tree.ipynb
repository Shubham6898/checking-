# %%
class Generic_tree_node:
    def __init__(self,data):
        self.data=data
        self.children=[]

root=Generic_tree_node(5)
root

# %%
class Generic_tree_node:
    def __init__(self,data):
        self.data=data
        self.children=[]
n1=Generic_tree_node(1)
n2=Generic_tree_node(2)
n3=Generic_tree_node(3)
n4=Generic_tree_node(4)
n5=Generic_tree_node(5)
n6=Generic_tree_node(6)
n7=Generic_tree_node(7)
n1.children.append(n2)
n1.children.append(n3)
n1.children.append(n4)
n3.children.append(n5)
n3.children.append(n6)
n4.children.append(n7)

# %%
# lets try to print the above generated generic tree
def print_tree(root):
    if root is None:
        return None  # this is not base case this time its edge case kyunki aabki bar kitne bhi no of children ho sakte hai
    print(root.data)
    for child in root.children:
        print_tree(child)
print_tree(n1)
# Out:
# 1
# 2
# 3
# 5
# 6
# 4
# 7

# %%
# lets try to print the above tree with little details:

def print_tree_details(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for child in root.children:
        print(child.data,end=', ')
    print()
    for child in root.children:
        print_tree_details(child)
print_tree_details(n1)
# Out:
# 1: 2, 3, 4,
# 2:
# 3: 5, 6,
# 5:
# 6:
# 4: 7,
# 7:

# %%
def take_input_generic_tree():
    print('Enter the root data: ')
    root_data=int(input())
    if root_data==-1:
        return None

    root=Generic_tree_node(root_data)
    print('Enter no of children for the node ',root.data)
    childern_count=int(input())
    for i in range(childern_count):
        child=take_input_generic_tree()
        root.children.append(child)
    return root
def print_tree_details(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for child in root.children:
        print(child.data,end=', ')
    print()
    for child in root.children:
        print_tree_details(child)
root=take_input_generic_tree()
print_tree_details(root)
# Out:
# Enter the root data:
# Enter no of children for the node  1
# Enter the root data:
# Enter no of children for the node  2
# Enter the root data:
# Enter no of children for the node  3
# Enter the root data:
# Enter no of children for the node  5
# Enter the root data:
# Enter no of children for the node  6
# Enter the root data:
# Enter no of children for the node  4
# Enter the root data:
# Enter no of children for the node  7
# 1: 2, 3, 4,
# 2:
# 3: 5, 6,
# 5:
# 6:
# 4: 7,
# 7:

# %%
def num_nodes(root):
    if root is None:
        return 0
    count=1
    for i in root.children:
        count+=num_nodes(i)
    return count

def take_input_generic_tree():
    print('Enter the root data: ')
    root_data=int(input())
    if root_data==-1:
        return None

    root=Generic_tree_node(root_data)
    print('Enter no of children for the node ',root.data)
    childern_count=int(input())
    for i in range(childern_count):
        child=take_input_generic_tree()
        root.children.append(child)
    return root
def print_tree_details(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for child in root.children:
        print(child.data,end=', ')
    print()
    for child in root.children:
        print_tree_details(child)

root=take_input_generic_tree()
print_tree_details(root)
print(num_nodes(root))
# Out:
# Enter the root data:
# Enter no of children for the node  1
# Enter the root data:
# Enter no of children for the node  2
# Enter the root data:
# Enter no of children for the node  3
# Enter the root data:
# Enter no of children for the node  5
# Enter the root data:
# Enter no of children for the node  6
# Enter the root data:
# Enter no of children for the node  4
# Enter the root data:
# Enter no of children for the node  7
# 1: 2, 3, 4,
# 2:
# 3: 5, 6,
# 5:
# 6:
# 4: 7,
# 7:
# 7

# %%
import queue
def take_input_generic_tree_level_wise():
    q=queue.Queue()
    print('Enter the root: ')
    root_data=int(input())
    if root_data==-1:
        return None
    root=Generic_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the children for ',current_node.data)
        num_children=int(input())
        for i in range(num_children):
            print("Enter the children for the root ",current_node.data)
            child_data=int(input())
            child=Generic_tree_node(child_data)
            current_node.children.append(child)
            q.put(child)
    return root
def print_tree_details(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for child in root.children:
        print(child.data,end=', ')
    print()
    for child in root.children:
        print_tree_details(child)
root=take_input_generic_tree_level_wise()
print_tree_details(root)
# Out:
# Enter the root:
# Enter the children for  1
# Enter the children for the root  1
# Enter the children for the root  1
# Enter the children for the root  1
# Enter the children for  2
# Enter the children for  3
# Enter the children for the root  3
# Enter the children for the root  3
# Enter the children for  4
# Enter the children for  5
# Enter the children for  6
# Enter the children for the root  6
# Enter the children for the root  6
# Enter the children for the root  6
# Enter the children for  7
# Enter the children for  8
# Enter the children for  9
# 1: 2, 3, 4,
# 2:
# 3: 5, 6,
# 5:
# 6: 7, 8, 9,
# 7:
# 8:
# 9:
# 4:

# %%
class Generic_tree_node:
    def __init__(self,data):
        self.data=data
        self.children=[]

def print_tree(root):
    if root is None:
        return None
    print(root.data)

    for i in root.children:
        print_tree(i)

def print_tree_details(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for i in root.children:
        print(i.data,end=', ')
    print()
    for i in root.children:
        print_tree_details(i)
    
    
n1=Generic_tree_node(1)
n2=Generic_tree_node(2)
n3=Generic_tree_node(3)
n4=Generic_tree_node(4)
n5=Generic_tree_node(5)
n6=Generic_tree_node(6)
n7=Generic_tree_node(7)
n1.children.append(n2)
n1.children.append(n3)
n1.children.append(n4)
n3.children.append(n5)
n3.children.append(n6)
n4.children.append(n7)
print_tree(n1)
print_tree_details(n1)
# Out:
# 1
# 2
# 3
# 5
# 6
# 4
# 7
# 1: 2, 3, 4,
# 2:
# 3: 5, 6,
# 5:
# 6:
# 4: 7,
# 7:

# %%
def take_input_generic_tree():
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Generic_tree_node(root_data)
    else:
        return None
    print('Enter the count of chilren for the node ',root.data)
    children_count=int(input())
    for i in range(children_count):
        child=take_input_generic_tree()
        root.children.append(child)
    return root

def print_tree_details(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for i in root.children:
        print(i.data,end=', ')
    print()
    for i in root.children:
        print_tree_details(i)
root=take_input_generic_tree()
print_tree_details(root)
# Out:
# Enter the root:
# Enter the count of chilren for the node  1
# Enter the root:
# Enter the count of chilren for the node  2
# Enter the root:
# Enter the count of chilren for the node  3
# Enter the root:
# Enter the count of chilren for the node  5
# Enter the root:
# Enter the count of chilren for the node  6
# Enter the root:
# Enter the count of chilren for the node  4
# Enter the root:
# Enter the count of chilren for the node  7
# 1: 2, 3, 4,
# 2:
# 3: 5, 6,
# 5:
# 6:
# 4: 7,
# 7:

# %%
def num_nodes(root):
    if root is None:
        return None
    count=1
    for child in root.children:
        count+=num_nodes(child)
    return count
def take_input_generic_tree():
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Generic_tree_node(root_data)
    else:
        return None
    print('Enter the count of chilren for the node ',root.data)
    children_count=int(input())
    for i in range(children_count):
        child=take_input_generic_tree()
        root.children.append(child)
    return root

def print_tree_details(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for i in root.children:
        print(i.data,end=', ')
    print()
    for i in root.children:
        print_tree_details(i)
root=take_input_generic_tree()
print_tree_details(root)
print("no of nodes",num_nodes(root))
# Out:
# Enter the root:
# Enter the count of chilren for the node  1
# Enter the root:
# Enter the count of chilren for the node  2
# Enter the root:
# Enter the count of chilren for the node  3
# Enter the root:
# Enter the count of chilren for the node  5
# Enter the root:
# Enter the count of chilren for the node  6
# Enter the root:
# Enter the count of chilren for the node  4
# Enter the root:
# Enter the count of chilren for the node  7
# 1: 2, 3, 4,
# 2:
# 3: 5, 6,
# 5:
# 6:
# 4: 7,
# 7:
# no of nodes 7

# %%
def take_input_generic_tree_level_wise():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Generic_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter no of the children for the node ',current_node.data)
        count_children=int(input())
        for i in range(count_children):
            print("Enter the next child for the node",current_node.data)
            child_data=int(input())
            child=Generic_tree_node(child_data)
            current_node.children.append(child)
            q.put(child)
    return root

def print_tree_details(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for i in root.children:
        print(i.data,end=', ')
    print()
    for i in root.children:
        print_tree_details(i)
root=take_input_generic_tree_level_wise()
print_tree_details(root)
# Out:
# Enter the root:
# Enter no of the children for the node  1
# Enter teh next child for the node 1
# Enter teh next child for the node 1
# Enter teh next child for the node 1
# Enter no of the children for the node  2
# Enter no of the children for the node  3
# Enter teh next child for the node 3
# Enter teh next child for the node 3
# Enter no of the children for the node  4
# Enter teh next child for the node 4
# Enter no of the children for the node  5
# Enter no of the children for the node  6
# Enter no of the children for the node  7
# 1: 2, 3, 4,
# 2:
# 3: 5, 6,
# 5:
# 6:
# 4: 7,
# 7:

# %%
class Generic_Tree_Node:
    def __init__(self,data):
        self.data=data
        self.children=[]

def print_generic_tree(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for i in root.children:
        print(i.data,end=', ')
    print()
    for i in root.children:
        print_generic_tree(i)

n1=Generic_Tree_Node(1)
n2=Generic_Tree_Node(2)
n3=Generic_Tree_Node(3)
n4=Generic_Tree_Node(4)
n5=Generic_Tree_Node(5)
n6=Generic_Tree_Node(6)
n7=Generic_Tree_Node(7)
n8=Generic_Tree_Node(8)
n9=Generic_Tree_Node(9)
n1.children.append(n2)
n1.children.append(n3)
n1.children.append(n4)
n2.children.append(n5)
n2.children.append(n6)
n5.children.append(n7)
n5.children.append(n8)
n8.children.append(n9)
print_generic_tree(n1)
# Out:
# 1: 2, 3, 4,
# 2: 5, 6,
# 5: 7, 8,
# 7:
# 8: 9,
# 9:
# 6:
# 3:
# 4:

# %%
def take_input_generic_tree():
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Generic_Tree_Node(root_data)
    else:
        return None
    print("Enter the no of childern for ",root.data)
    children_count=int(input())
    for i in range(children_count):
        child=take_input_generic_tree()
        root.children.append(child)
    return root
def print_generic_tree(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for i in root.children:
        print(i.data,end=', ')
    print()
    for i in root.children:
        print_generic_tree(i)
root=take_input_generic_tree()
print_generic_tree(root)
# Out:
# Enter the root:
# Enter the no of childern for  1
# Enter the root:
# Enter the no of childern for  2
# Enter the root:
# Enter the no of childern for  5
# Enter the root:
# Enter the no of childern for  7
# Enter the root:
# Enter the no of childern for  8
# Enter the root:
# Enter the no of childern for  9
# Enter the root:
# Enter the no of childern for  3
# Enter the root:
# Enter the no of childern for  4
# Enter the root:
# Enter the no of childern for  6
# 1: 2, 4, 6,
# 2: 5, 3,
# 5: 7, 8,
# 7:
# 8: 9,
# 9:
# 3:
# 4:
# 6:

# %%
def num_nodes(root):
    if root is None:
        return 0
    count=1
    for i in root.children:
        count+=num_nodes(i)
    return count

def take_input_generic_tree():
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Generic_Tree_Node(root_data)
    else:
        return None
    print("Enter the no of childern for ",root.data)
    children_count=int(input())
    for i in range(children_count):
        child=take_input_generic_tree()
        root.children.append(child)
    return root
def print_generic_tree(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for i in root.children:
        print(i.data,end=', ')
    print()
    for i in root.children:
        print_generic_tree(i)
root=take_input_generic_tree()
print_generic_tree(root)
print(num_nodes(root))
# Out:
# Enter the root:
# Enter the no of childern for  1
# Enter the root:
# Enter the no of childern for  2
# Enter the root:
# Enter the no of childern for  5
# Enter the root:
# Enter the no of childern for  7
# Enter the root:
# Enter the no of childern for  8
# Enter the root:
# Enter the no of childern for  9
# Enter the root:
# Enter the no of childern for  6
# Enter the root:
# Enter the no of childern for  3
# Enter the root:
# Enter the no of childern for  4
# 1: 2, 3, 4,
# 2: 5, 6,
# 5: 7, 8,
# 7:
# 8: 9,
# 9:
# 6:
# 3:
# 4:
# 9

# %%
import queue
def num_nodes(root):
    if root is None:
        return 0
    count=1
    for i in root.children:
        count+=num_nodes(i)
    return count

def take_input_level_wise():
    q=queue.Queue()
    print("Enter the root ")
    root_data=int(input())
    if root_data!=-1:
        root=Generic_Tree_Node(root_data)
    else:
        return None
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print("Enter the number of childern for ",current_node.data)
        num_child=int(input())
        for i in range(num_child):
            print("Enter tyhe next child for ",current_node.data)
            child_data=int(input())
            child=Generic_Tree_Node(child_data)
            current_node.children.append(child)
            q.put(child)
    return root

    
def print_generic_tree(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for i in root.children:
        print(i.data,end=', ')
    print()
    for i in root.children:
        print_generic_tree(i)
root=take_input_level_wise()
print_generic_tree(root)
print(num_nodes(root))
# Out:
# Enter the root
# Enter the number of childern for  1
# Enter tyhe next child for  1
# Enter tyhe next child for  1
# Enter tyhe next child for  1
# Enter the number of childern for  2
# Enter tyhe next child for  2
# Enter tyhe next child for  2
# Enter the number of childern for  3
# Enter tyhe next child for  3
# Enter tyhe next child for  3
# Enter the number of childern for  4
# Enter the number of childern for  5
# Enter tyhe next child for  5
# Enter the number of childern for  6
# Enter tyhe next child for  6
# Enter the number of childern for  7
# Enter the number of childern for  8
# Enter the number of childern for  9
# Enter the number of childern for  1
# 1: 2, 3, 4,
# 2: 5, 6,
# 5: 9,
# 9:
# 6: 1,
# 1:
# 3: 7, 8,
# 7:
# 8:
# 4:
# 10

# %%
class Generic_tree_node:
    def __init__(self,data):
        self.data=data
        self.children=[]

def print_generic_tree(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for i in root.children:
        print(i.data,end=', ')
    print()
    for i in root.children:
        print_generic_tree(i)
n1=Generic_tree_node(1)
n2=Generic_tree_node(2)
n3=Generic_tree_node(3)
n4=Generic_tree_node(4)
n5=Generic_tree_node(5)
n6=Generic_tree_node(6)
n7=Generic_tree_node(7)
n1.children.append(n2)
n1.children.append(n3)
n1.children.append(n4)
n3.children.append(n5)
n3.children.append(n6)
n4.children.append(n7) 
print_generic_tree(n1)
# Out:
# 1: 2, 3, 4,
# 2:
# 3: 5, 6,
# 5:
# 6:
# 4: 7,
# 7:

# %%
class Generic_tree_node:
    def __init__(self,data):
        self.data=data
        self.children=[]

def print_generic_tree(root):
    if root is None:
        return None
    print(root.data,end=': ')
    for i in root.children:
        print(i.data,end=', ')
    print()
    for i in root.children:
        print_generic_tree(i)
        
def take_input_rec():
    print("Enter the root")
    root_data=int(input())
    if root_data==-1:
        return None
    root=Generic_tree_node(root_data)
    print("Enter no of children for the node ",root.data)
    child_count=int(input())
    for i in range(child_count):
        child=take_input_rec()
        root.children.append(child)
    return root

root=take_input_rec()
print_generic_tree(root)
# Out:
# Enter the root
# Enter no of children for the node  1
# Enter the root
# Enter no of children for the node  2
# Enter the root
# Enter no of children for the node  3
# Enter the root
# Enter no of children for the node  5
# Enter the root
# Enter no of children for the node  6
# Enter the root
# Enter no of children for the node  4
# Enter the root
# Enter no of children for the node  7
# 1: 2, 3, 4,
# 2:
# 3: 5, 6,
# 5:
# 6:
# 4: 7,
# 7:
