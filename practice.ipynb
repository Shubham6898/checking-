# %%
a=[[2, 0], [2, 1], [1, 2], [3, 3], [1, 4]]
a.sort()
for  i in a:
    print(i)
# Out:
# [1, 2]
# [1, 4]
# [2, 0]
# [2, 1]
# [3, 3]

# %%
s=[i[0] for i in a]
s
# Out:
# [1, 1, 2, 2, 3]

# %% [markdown]
# # 13 June Revision

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
    
def take_input():
    l=list(map(int,input().split()))
    if len(l)==0 or l[0]==-1:
        return None
    i=0
    node=Node(l[i])
    i+=1
    cur_node=node
    while i<len(l):
        if l[i]==-1:
            break
        else:
            
            new_node=Node(l[i])
            cur_node.next=new_node
            cur_node=new_node
        i+=1
    return node
def print_ll(head):
    if head is None:
        print('None')
        return 
    while head is not None:
        print(head.data,end='-->')
        head=head.next
    print('None')
head=take_input()
print_ll(head)
# Out:
# 1-->2-->3-->4-->5-->None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
    
def take_input():
    l=list(map(int,input().split()))
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
    return head
def print_ll(head):
    if head is None:
        print('None')
        return 
    while head is not None:
        print(head.data,end='-->')
        head=head.next
    print('None')
head=take_input()
print_ll(head)
# Out:
# 1-->2-->3-->4-->5-->None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def take_input():
    l=list(map(int,input().split()))
    if len(l)==0 or l[0]==-1:
        return None
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
    return head

def print_ll(head):
    while head is not None:
        print(head.data,end='--->')
        head=head.next
    print('None')
    return
def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c

def insert(head,pst,data):
    if pst<0 or pst>length(head):
        return head
    new_node=Node(data)
    curr=head
    prev=None
    i=0
    while i<pst:
        prev=curr
        curr=curr.next
        i+=1
    if curr==head: # that is insert at 0th pst
        new_node.next=head
        head=new_node
    else:
        prev.next=new_node
        new_node.next=curr
    return head
ll=take_input()
print_ll(ll)
new_ll=insert(ll,2,6) # somewher mid
print_ll(new_ll)
new_ll_ll=insert(new_ll,0,8)  # in starting
print_ll(new_ll_ll)
new_ll_ll_ll=insert(new_ll_ll,length(new_ll_ll),99)# in end
print_ll(new_ll_ll_ll)
# Out:
# 1--->2--->3--->4--->5--->None
# 1--->2--->6--->3--->4--->5--->None
# 8--->1--->2--->6--->3--->4--->5--->None
# 8--->1--->2--->6--->3--->4--->5--->99--->None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def take_input():
    l=list(map(int,input().split()))
    if len(l)==0 or l[0]==-1:
        return None
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
    return head

def print_ll(head):
    while head is not None:
        print(head.data,end='--->')
        head=head.next
    print('None')
    return
def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c

def insert_rec(head,pst,data):
    if pst<0 or pst>length(head):
        return head
    if pst==0:
        new_node=Node(data)
        new_node.next=head
        head=new_node
        return head
    curr=head
    new_ll=insert_rec(curr.next,pst-1,data)
    head.next=new_ll
    return head
    
    
ll=take_input()
print_ll(ll)
new_ll=insert_rec(ll,2,6) # somewher mid
print_ll(new_ll)
new_ll_ll=insert_rec(new_ll,0,8)  # in starting
print_ll(new_ll_ll)
new_ll_ll_ll=insert_rec(new_ll_ll,length(new_ll_ll),99)# in end
print_ll(new_ll_ll_ll)
# Out:
# 1--->2--->3--->4--->5--->None
# 1--->2--->6--->3--->4--->5--->None
# 8--->1--->2--->6--->3--->4--->5--->None
# 8--->1--->2--->6--->3--->4--->5--->99--->None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
def take_input():
    l=list(map(int,input().split()))
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            
            tail.next=new_node 
            tail=new_node
            
    return head

def print_ll(head):
    while head is not None:
        print(head.data,end='--->')
        head=head.next
    print('None')
    return
def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c
def delete(head,pst):  # 0th index deletion
    if pst<0 or pst>=length(head):
        return head
    i=0
    prev=None
    curr=head
    while i<pst:
        prev=curr
        curr=curr.next
        i+=1
    if curr==head: # that is at 0th pst
        head=head.next
    elif curr.next==None: # last pst:
        prev.next=None
    else:
        prev.next=curr.next
    return head

head=take_input()
print_ll(head)
del1=delete(head,3)
print_ll(del1)
del2=delete(del1,0)
print_ll(del2)
del3=delete(del2,length(del2)-1)
print_ll(del3)       
del4=delete(del3,length(del3))
print_ll(del4)
# Out:
# 1--->2--->3--->4--->5--->6--->7--->8--->9--->None
# 1--->2--->3--->5--->6--->7--->8--->9--->None
# 2--->3--->5--->6--->7--->8--->9--->None
# 2--->3--->5--->6--->7--->8--->None
# 2--->3--->5--->6--->7--->8--->None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
def take_input():
    l=list(map(int,input().split()))
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            
            tail.next=new_node 
            tail=new_node
            
    return head

def print_ll(head):
    while head is not None:
        print(head.data,end='--->')
        head=head.next
    print('None')
    return
def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c
def delete_data(head,data):  # 0th index deletion
    if head==None:
        return None
    prev=None
    curr=head
    while curr.data!=data and curr.next!=None:
        prev=curr
        curr=curr.next
    if curr==head: # that is at 0th pst
        head=head.next
    elif curr.next==None: # last pst:
        prev.next=None
    else:
        prev.next=curr.next
    return head
head=take_input()
print_ll(head)
del1=delete_data(head,3)
print_ll(del1)
del2=delete_data(del1,1)
print_ll(del2)
del3=delete_data(del2,9)
print_ll(del3)
# Out:
# 1--->2--->3--->4--->5--->6--->7--->8--->9--->None
# 1--->2--->4--->5--->6--->7--->8--->9--->None
# 2--->4--->5--->6--->7--->8--->9--->None
# 2--->4--->5--->6--->7--->8--->None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

def take_input():
    l=list(map(int,input().split()))
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
            
    return head

def print_ll(head):
    while head is not None:
        print(head.data,end='-->')
        head=head.next
        
    print('None')
    return

def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c

def reverse(head):
    if head== None or head.next==None:
        return head
    
    small_head=reverse(head.next)
    curr=small_head
    while curr.next!=None:
        curr=curr.next
    curr.next=head
    head.next=None
    return small_head
head=take_input()
print_ll(head)
rev=reverse(head)
print_ll(rev)
# Out:
# 1-->2-->3-->4-->5-->6-->None
# 6-->5-->4-->3-->2-->1-->None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

def take_input():
    l=list(map(int,input().split()))
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
            
    return head

def print_ll(head):
    while head is not None:
        print(head.data,end='-->')
        head=head.next
        
    print('None')
    return

def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c

def reverse_2(head):
    if head== None or head.next==None:
        return head,head
    
    small_head,tail=reverse_2(head.next)
    tail.next=head
    head.next=None
    return small_head,head
head=take_input()
print_ll(head)
rev,head=reverse_2(head)
print_ll(rev)
print_ll(head)
# Out:
# 1-->2-->3-->4-->5-->6-->None
# 6-->5-->4-->3-->2-->1-->None
# 1-->None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

def take_input():
    l=list(map(int,input().split()))
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
            
    return head

def print_ll(head):
    while head is not None:
        print(head.data,end='-->')
        head=head.next
        
    print('None')
    return

def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c

def reverse_3(head):
    if head== None or head.next==None:
        return head
    
    small_head=reverse_3(head.next)
    tail=head.next
    tail.next=head
    head.next=None
    return small_head
head=take_input()
print_ll(head)
rev=reverse_3(head)
print_ll(rev)
# Out:
# 1-->2-->3-->4-->5-->6-->None
# 6-->5-->4-->3-->2-->1-->None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

def take_input():
    l=list(map(int,input().split()))
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
            
    return head

def print_ll(head):
    while head is not None:
        print(head.data,end='-->')
        head=head.next
        
    print('None')
    return

def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c

def reverse_itt(head):
    if head== None :
        return head
    
    prev=None
    curr=head
    while curr is not None:
        next_ele=curr.next
        curr.next=prev
        prev=curr
        curr=next_ele
    head=prev
    return head
    
    
head=take_input()
print_ll(head)
rev=reverse_itt(head)
print_ll(rev)
# Out:
# 1-->2-->3-->4-->5-->6-->None
# 6-->5-->4-->3-->2-->1-->None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

def take_input():
    l=list(map(int,input().split()))
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
    return head

def print_ll(head):
    while head is not None:
        print(head.data,end='-->')
        head=head.next
    print('None')
    return 


def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c

def mid_point(head):
    if head is None :
        return head
    l=length(head)
    if l%2==0:
        mid_pst=l//2
    else:
        mid_pst=l//2+1
    i=0
    print(mid_pst)
    curr=head
    while i<mid_pst-1:
        i+=1
        curr=curr.next
        
        
    return curr.data

head=take_input()
print_ll(head)
print(mid_point(head))
# Out:
# 1-->2-->3-->4-->5-->6-->7-->None
# 4
# 4

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

def print_ll(head):
    while head is not None:
        print(head.data,end='-->')
        head=head.next
    print('None')
    return 


def take_input():
    l=list(map(int,input().split()))
    if len(l)==0 or l[0]==-1:
        return None
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
    return head


def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c

def mid_point_2(head):
    if head is None:
        return None
    slow=head
    fast=head
    
    while fast.next!=None and fast.next.next!=None:
        slow=slow.next
        fast=fast.next.next
    return slow.data
    
head=take_input()
print_ll(head)
print(mid_point_2(head))
# Out:
# 1-->2-->3-->4-->5-->6-->None
# 3

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

def take_input():
    l=list(map(int,input().split()))
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
    return head

def length(head):
    c=0
    while head is not None:
        c++1
        head=head.next
    return c

def print_ll(head):
    while head is not None:
        print(head.data,end='-->')
        head=head.next
    print('None')
    return 

def merge(head1,head2):
    if head1 is None:
        return head2
    if head2 is None:
        return head1
    if head1.data>head2.data:
        f_head,f_tail=head2,head2
        head2=head2.next
    else:
        f_head,f_tail=head1,head1
        head1=head1.next
    while head1!=None and head2!=None:
        if head1.data>head2.data:
            f_tail.next=head2
            f_tail=head2
            head2=head2.next
        else:
            f_tail.next=head1
            f_tail=head1
            head1=head1.next
    while head1 is not None:
        f_tail.next=head1
        f_tail=head1
        head1=head1.next
    while head2 is not None:
        f_tail.next=head2
        f_tail=head2
        head2=head2.next
    return f_head

head1=take_input()
print_ll(head1)
head2=take_input()
print_ll(head2)
print_ll(merge(head1,head2))  # both list need to be sorted
# Out:
# 2-->4-->5-->6-->7-->None
# 1-->3-->4-->8-->9-->None
# 1-->2-->3-->4-->4-->5-->6-->7-->8-->9-->None

# %%
class Stack:
    def __init__(self,max_l):
        self.data=[]
        self.limit=max_l
        self.count=0
        
    def push(self,ele):
        if self.count<self.limit:
            self.data.append(ele)
            self.count+=1
        else:
            print("Stack is full cant push")
        return
    
    def pop(self):
        if self.count>0:
            ele=self.data.pop()
            self.count-=1
            return ele
        else:
            print('Stack is empty cant pop.')
            return 
    def top(self):
        if self.count>0:
            ele=self.data[-1]
            return (ele)
        else:
            print("Stack is empty not any top.")
            return 
        
    def length(self):
        return self.count
    def isEmpty(self):
        return self.count==0
    
s=Stack(6)
s.push(1)
s.push(2)
s.push(3)
s.push(4)
s.push(5)
print(s.top())
while s.isEmpty()!=True:
    print(s.pop())
s.top()
# Out:
# 5
# 5
# 4
# 3
# 2
# 1
# Stack is empty not any top.

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class Stack_ll:
    def __init__(self,limit):
        self.count=0
        self.limit=limit
        self.head=None
    
    def push(self,data):
        new_node=Node(data)
        if self.count<self.limit:
            new_node.next=self.head
            self.head=new_node
            self.count+=1
        else:
            print('Stack is full cant push')
            return
    def pop(self):
        if self.count>0:
            ele=self.head.data
            self.head=self.head.next
            self.count-=1
            return ele
        else:
            print('Stack is empty dont have top.')
            
    def top(self):
        if self.count>0:
            return self.head.data
        else:
            print('Stack is empty doesnt have top')
            return
    def size(self):
        return self.count
    def isEmpty(self):
        return self.count==0

s=Stack_ll(6)
s.push(1)
s.push(2)
s.push(3)
s.push(4)
s.push(5)
print(s.top())
while s.isEmpty()!=True:
    print(s.pop())
s.top()
# Out:
# 5
# 5
# 4
# 3
# 2
# 1
# Stack is empty doesnt have top

# %%
import queue
s=queue.LifoQueue()
s.put(1)
s.put(2)
s.put(3)
s.put(4)
while s.empty()!=True:
    print(s.get())
# Out:
# 4
# 3
# 2
# 1

# %%
import queue
q=queue.Queue()
q.put(1)
q.put(2)
q.put(3)
q.put(4)
while q.empty()!=True:
    print(q.get())
# Out:
# 1
# 2
# 3
# 4

# %%
# params:
def params(string):
    s=[]
    for i in string:
        if i =='(' or i =='{' or i=='[':
            s.append(i)
        elif i==')':
            if len(s)>0  and s[-1]=='(':
                s.pop()
            else:
                s.append(i)
        elif i ==']':
            if len(s)>0 and s[-1]=='[':
                s.pop()
            else:
                s.append(i)
        elif i=='}':
            if len(s)>0 and s[-1]=='{':
                s.pop()
            else:
                s.append(i)
        else:
            s.append(i)
            
    if len(s)==0:
        return True
    return False

string=input()
params(string)
# Out:
# True

# %%
def reverse_stack(s1,s2):
    if len(s1)<=1:
        return s1
    while len(s1)>1:
        s2.append(s1.pop())
    first=s1.pop()
    while len(s2)>0:
        s1.append(s2.pop())
    reverse_stack(s1,s2)
    s1.append(first)
    return s1
s1=list(map(int,input().split()))
s2=[]
print(reverse_stack(s1,s2))
# Out:
# [5, 4, 3, 2, 1]

# %%
class Queue:
    def __init__(self,limit):
        self.queue=[]
        self.count=0
        self.limit=limit
    def enqueue(self,data):
        if self.count<self.limit:
            self.queue.append(data)
            self.count+=1
        else:
            print('Queue is full cant enqueue.')
            return 
    def dequeue(self):
        if self.count>0:
            ele=self.queue.pop(0)
            self.count-=1
            return ele
        else:
            print('Queue is empty cant dequeue.')
    def front(self):
        if self.count>0:
            return self.queue[0]
        else:
            print("Queue is empty doesnt have front.")
            return
    def size(self):
        return self.count
    def isEmpty(self):
        return self.count==0
    
    
q=Queue(6)
q.enqueue(1)
q.enqueue(2)
q.enqueue(3)
q.enqueue(4)
q.enqueue(5)
print(q.front())
while q.isEmpty()!=True:
    print(q.dequeue())
(q.front())
(q.dequeue())
# Out:
# 1
# 1
# 2
# 3
# 4
# 5
# Queue is empty doesnt have front.
# Queue is empty cant dequeue.

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class Queue_ll:
    def __init__(self,limit):
        self.limit=limit
        self.head=None
        self.tail=None
        self.count=0
    def enqueue(self,data):
        if self.count<self.limit:
            new_node=Node(data)
            if self.head==None:
                self.head,self.tail=new_node,new_node
            else:
                self.tail.next=new_node
                self.tail=new_node
            self.count+=1
                
        else:
            print("Queue is full for enqueuing operation.")
    
    def dequeue(self):
        if self.count>0:
            ele=self.head.data
            self.head=self.head.next
            self.count-=1
            
            return ele
        else:
            print("Queue is empty cant dequeue")
            return 
        
    def front(self):
        if self.count>0:
            ele=self.head.data
            return ele
        else:
            print("Queue is empty so not any front")
            return
                
    def size(self):
        return self.count
    
    def isEmpty(self):
        return self.count==0
    

q=Queue_ll(6)
q.enqueue(1)
q.enqueue(2)
q.enqueue(3)
q.enqueue(4)
q.enqueue(5)
print(q.front())
while q.isEmpty()!=True:
    print(q.dequeue())
(q.front())
(q.dequeue())
# Out:
# 1
# 1
# 2
# 3
# 4
# 5
# Queue is empty so not any front
# Queue is empty cant dequeue

# %%
class doubly_linked_list:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None

def take_input():
    l=list(map(int,input().split()))
    if len(l)==0 or l[0]==-1:
        return None
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=doubly_linked_list(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
    return head

def print_dll(head):
    print('None',end='<-->')
    while head is not None:
        print(head.data,end='<-->')
        head=head.next
    print('None')
    return

def length(head):
    c=0
    while head is not None:   
        c+=1
        head=head.next
    return c

def  insert_dll(head,pst,data):
    if head is None:
        return None
    if pst<0 or pst>length(head):
        return head
    
    i=0
    new_node=doubly_linked_list(data)
    curr=head
    pre=None
    while i<pst:
        pre=curr
        curr=curr.next
        i+=1
        
    if pre==None and curr==head:  # at zeroth post
        new_node.next=head
        head.prev=new_node
        new_node.prev=None
        head=new_node
        
    elif curr.next==None: # last pst
        curr.next=new_node
        new_node.prev=curr
        new_node.next=None
    else:
        pre.next=new_node
        new_node.next=curr
        curr.prev=new_node
        new_node.prev=pre
    return head

head=take_input()
print_dll(head)
head1=(insert_dll(head,2,99))
print_dll(head1)
head2=(insert_dll(head1,0,199))
print_dll(head2)
head3=(insert_dll(head2,length(head2)-1,299)) 
print_dll(head3)
# Out:
# None<-->1<-->2<-->3<-->4<-->5<-->6<-->None
# None<-->1<-->2<-->99<-->3<-->4<-->5<-->6<-->None
# None<-->199<-->1<-->2<-->99<-->3<-->4<-->5<-->6<-->None
# None<-->199<-->1<-->2<-->99<-->3<-->4<-->5<-->6<-->299<-->None

# %%
class doubly_linked_list:
    def __init__(self,data):
        self.data=data
        self.prev=None
        self.next=None

def take_input():
    l=list(map(int,input().split()))
    if len(l)<0 or l[0]==-1:
        return None
    head,tail=None,None
    for i in l:
        if i==-1:
            break
        new_node=Node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
    return head

def print_dll(head):
    print('None',end='<-->')
    while head is not None:
        print(head.data,end='<-->')
        head=head.next
    print('None')
    return
def length(head):
    c=0
    while head is not None:
        c+=1
        head=head.next
    return c

def delete_dll(head,pst):
    if head is None:
        return head
    if pst<0 or pst>length(head)-1:
        return head
    i=0
    curr=head
    pre=None
    while i<pst:
        pre=curr
        curr=curr.next
        i+=1
    
    if pre==None and curr==head:  # zeroth pst
        head=head.next
        head.prev=None
    elif curr.next==None:
        pre.next=None
    else:
        pre.next=curr.next
        curr.next.prev=pre
    return head
        
head=take_input()
print_dll(head)
print("Deletion") 
print_dll(delete_dll(head,2))   
head=take_input()
print_dll(head)
print("Deletion") 
print_dll(delete_dll(head,0))      
head=take_input()
print_dll(head)
print("Deletion") 
print_dll(delete_dll(head,length(head)-1))
# Out:
# None<-->1<-->2<-->3<-->4<-->5<-->6<-->7<-->8<-->9<-->None
# Deletion
# None<-->1<-->2<-->4<-->5<-->6<-->7<-->8<-->9<-->None
# None<-->1<-->2<-->3<-->4<-->5<-->6<-->7<-->8<-->9<-->None
# Deletion
# None<-->2<-->3<-->4<-->5<-->6<-->7<-->8<-->9<-->None
# None<-->1<-->2<-->3<-->4<-->5<-->6<-->7<-->8<-->9<-->None
# Deletion
# None<-->1<-->2<-->3<-->4<-->5<-->6<-->7<-->8<-->None

# %%
class Circular_node:
    def __init__(self,data):
        self.data=data
        self.next=None
    
def take_input():
    l=list(map(int,input().split()))
    if len(l)==0 or l[0]==-1:
        return None
    head,tail=None,None
    for i in l:
        if i ==-1:
            tail.next=new_node
            break
        new_node=Circular_node(i)
        if head is None:
            head,tail=new_node,new_node
        else:
            tail.next=new_node
            tail=new_node
    
    return head

def length(head):
    c=1
    curr=head.next
    while curr != head:
        c+=1
        curr=curr.next
    return c

def print_cll(head):
    print(head.data,end='-->')
    curr=head.next
    while curr !=head:
        print(curr.data,end='-->')
        curr=curr.next
    print(head.data)
    return 


def insert(head,pst,data):
    if head is None:
        return None
    if pst<0 or len(head)<pst:
        return head
    prev=None
    curr=head
    i=0
    while i<pst:
        prev=curr
        curr=curr.next
        i+=1

# %%
2 is not 3
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /var/folders/9k/hwvxv5h918d04z4jvndsxz400000gn/T/ipykernel_88018/2231232904.py:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   2 is not 3
# True

# %%
class useer:
    
    def burcklen(cls, input1,input2):
        if input1 < 0:
            return 0
        if input1 == 0:
            return 1
    
        count = 0
        for i in range(1, input2+ 1):
            count += cls.burcklen(input1 -
                                  i, input2)
    
        return count
c=useer()
n=int(input())
s=int(input())
print(c.burcklen(n,s))
# Out:
# 5
