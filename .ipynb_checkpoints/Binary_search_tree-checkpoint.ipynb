# %% [markdown]
# # BST is Binary Search Tree so hoga toh binary tree means max 2 child but :
# # In BST  :-     left_root.data<=root.data<=right_root.data
# basically root ke left mei sab chote node hogi aur root ke right mei jitni bhi node hai sab bdi hogi root se

# %%
# lets search in BST:

import queue
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
def BST(root,x):
        if root is None:
            return -1
        if root.data==x:
            return "FOUND"
        if root.data>x:
            return BST(root.left,x)
        else:
            return  BST(root.right,x)
def level_wise_input():
        q=queue.Queue()
        print("Enter root")
        root_data=int(input())
        if root_data!=-1:
            root=Binary_tree_node(root_data)
        else:
            return None
        q.put(root)
        while q.empty()!=True:
            current_node=q.get()
            print("Enter the left child of node",current_node.data)
            left_child=int(input())
            if left_child!=-1:
                left_node=Binary_tree_node(left_child)
                current_node.left=left_node
                q.put(left_node)
            
            print("Enter the right child of node",current_node.data)
            right_child=int(input())
            if right_child!=-1:
                right_node=Binary_tree_node(right_child)
                current_node.right=right_node
                q.put(right_node)
        return root
root=level_wise_input()
print("Enter the node want to search")
x=int(input())
node=BST(root,x)
if node=="FOUND":
    print("Element found")
else:
    print("Element not found")
# Out:
# Enter root
# Enter the left child of node 20
# Enter the right child of node 20
# Enter the left child of node 8
# Enter the right child of node 8
# Enter the left child of node 22
# Enter the right child of node 22
# Enter the left child of node 4
# Enter the right child of node 4
# Enter the left child of node 12
# Enter the right child of node 12
# Enter the left child of node 10
# Enter the right child of node 10
# Enter the left child of node 14
# Enter the right child of node 14
# Enter the node want to search
# Element not found

# %%
print(type(root))
# Out:
# <class '__main__.Binary_tree_node'>

# %%
import queue
class BST:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
def print_bw_k1_k2(root,k1,k2):
    if root is None:
        return None
    if k1>root.data:
        print_bw_k1_k2(root.right,k1,k2)
    elif root.data>k2:
        print_bw_k1_k2(root.left,k1,k2)
    else:
        print(root.data)
        print_bw_k1_k2(root.left,k1,k2)
        print_bw_k1_k2(root.right,k1,k2)
    #return root

def level_wise_input():
        q=queue.Queue()
        print("Enter root")
        root_data=int(input())
        if root_data!=-1:
            root=Binary_tree_node(root_data)
        else:
            return None
        q.put(root)
        while q.empty()!=True:
            current_node=q.get()
            print("Enter the left child of node",current_node.data)
            left_child=int(input())
            if left_child!=-1:
                left_node=Binary_tree_node(left_child)
                current_node.left=left_node
                q.put(left_node)
            
            print("Enter the right child of node",current_node.data)
            right_child=int(input())
            if right_child!=-1:
                right_node=Binary_tree_node(right_child)
                current_node.right=right_node
                q.put(right_node)
        return root

root=level_wise_input()
print("ENTER THE RANGE:")


k1,k2=list(map(int,input().split()))
print_bw_k1_k2(root,k1,k2)
# Out:
# Enter root
# Enter the left child of node 4
# Enter the right child of node 4
# Enter the left child of node 2
# Enter the right child of node 2
# Enter the left child of node 6
# Enter the right child of node 6
# Enter the left child of node 1
# Enter the right child of node 1
# Enter the left child of node 3
# Enter the right child of node 3
# ENTER THE RANGE:
# 4
# 2
# 3

# %%
import queue
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def BST(root,ele):
    if root is None:
        return -1
    if root.data==ele:
        return 'Element Found'
    if root.data>ele:
        return BST(root.left,ele)
    else:

        return BST(root.right,ele)
    return 'Not Found'

def level_wise_input():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
    

root=level_wise_input()
print('Enter the ele to search in tree ')
ele=int(input())
node=BST(root,ele)
print(node)
# Out:
# Enter the root:
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  1
# Enter the right child for  1
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  33
# Enter the right child for  33
# Enter the ele to search in tree
# -1

# %%
import queue
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def BST(root,ele):
    if root is None:
        return -1
    if root.data==ele:
        return 'Element Found'
    if root.data>ele:
        return BST(root.left,ele)
    else:

        return BST(root.right,ele)
    return 'Not Found'

def print_bw_k1_k2(root,k1,k2):
    if root is None:
        return None
    if root.data>k2:
        print_bw_k1_k2(root.left,k1,k2)
    elif root.data<k1:
        print_bw_k1_k2(root.right,k1,k2)
    else:
        print(root.data)
        print_bw_k1_k2(root.left,k1,k2)
        print_bw_k1_k2(root.right,k1,k2)
    return

def level_wise_input():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
    

root=level_wise_input()

(print_bw_k1_k2(root,2,7))
# Out:
# Enter the root:
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  2
# Enter the right child for  2
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  1
# Enter the right child for  1
# Enter the left child for  3
# Enter the right child for  3
# 4
# 2
# 3
# 6

# %%
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def construct_BST(arr):
    if len(arr)==0 :
        return None
    root_data=arr[len(arr)//2]
    root=Binary_tree_node(root_data)
    root.left=construct_BST(arr[:len(arr)//2])
    root.right=construct_BST(arr[len(arr)//2+1:])
    return root

def print_tee_detailed(root):
    if root is None:
        return
    print(root.data,end=': ')
    if root.left!=None:
        print('L',root.left.data,end=', ')
    if root.right!=None:
        print('R',root.right.data)
    print()
    print_tee_detailed(root.left)
    print()
    print_tee_detailed(root.right)

arr=[1,2,3]
root=construct_BST(arr)
print_tee_detailed(root)
# Out:
# 2: L 1, R 3
#
# 1:
#
#
# 3:

# %%
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def minTree(root):
    if root is None:
        return float('inf')
    left_min=minTree(root.left)
    right_min=minTree(root.right)
    return min(left_min,right_min,root.data)

def maxTree(root):
    if root is None:
        return -float('inf')
    left_max=maxTree(root.left)
    right_max=maxTree(root.right)
    return max(left_max,right_max,root.data)

def check_bst(root):
    if root is None:
        return True
    left_max=maxTree(root.left)
    right_min=minTree(root.right)
    if left_max>root.data or right_min<root.data:
        return False
    is_left_BST=check_bst(root.left)
    is_right_BST=check_bst(root.right)
    return is_left_BST and is_right_BST

def level_wise_input():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
    

root=level_wise_input()
print(check_bst(root))
# Out:
# Enter the root:
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  3
# Enter the right child for  3
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  1
# Enter the right child for  1
# Enter the left child for  2
# Enter the right child for  2
# Enter the left child for  11
# Enter the right child for  11
# Enter the left child for  3
# Enter the right child for  3
# False

# %%
def is_bst_2(root):
    if root is None:
        return 1000000,-1000000,True # min,max and hai bst ya nhi

    left_min,left_max,is_left_bst=is_bst_2(root.left) # left side ka min,max and checking if left bst or not
    right_min,right_max,is_right_bst=is_bst_2(root.right) # right side ka min , max and checking if right side is bst or not

    overall_minm=min(left_min,right_min,root.data) # pure tree ka minm element kaunsa hai
    overall_mxm=max(left_max,right_max,root.data) # pure tree ka maxm element kaunsa hai
    
    istreebst=True  # yeh ek boolean
    if root.data<=left_max or root.data>=right_min:
        istreebst=False
    if not(is_left_bst) or not(is_right_bst):
        istreebst=False
    return (overall_minm,overall_mxm,istreebst)

    
def level_wise_input():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
    

root=level_wise_input()
print(is_bst_2(root))
# Out:
# Enter the root:
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  2
# Enter the right child for  2
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  1
# Enter the right child for  1
# Enter the left child for  3
# Enter the right child for  3
# (1, 6, True)

# %%
def is_bst_3(root,min_range,max_range):
    if root is None:
        return True
    if root.data<min_range or root.data>max_range:
        return False
    is_left_within_range=is_bst_3(root.left,min_range,root.data-1)
    is_right_within_range=is_bst_3(root.right,root.data,max_range)
    return is_left_within_range and is_right_within_range



    
def level_wise_input():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
    

root=level_wise_input()
print(is_bst_3(root,-100000,100000))
# Out:
# Enter the root:
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  7
# Enter the right child for  7
# False

# %%
def node_to_root_path(root,node_data):
    if root is None:
        return None
    
    if root.data==node_data:
        l=[]
        l.append(root.data)
        return l
    left_op=node_to_root_path(root.left,node_data)
    if left_op!=None:
        left_op.append(root.data)
        return left_op
    right_op=node_to_root_path(root.right,node_data)
    if right_op!=None:
        right_op.append(root.data)
        return right_op
    return None

def level_wise_input():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
    

root=level_wise_input()
print(node_to_root_path(root,8))
# Out:
# Enter the root:
# Enter the left child for  1
# Enter the right child for  1
# Enter the left child for  2
# Enter the right child for  2
# Enter the left child for  3
# Enter the right child for  3
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  5
# Enter the right child for  5
# Enter the left child for  9
# Enter the right child for  9
# Enter the left child for  7
# Enter the right child for  7
# Enter the left child for  8
# Enter the right child for  8
# [8, 5, 6, 3, 1]

# %%
import queue
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def BST(root,x):
    if root is None:
        return -1
    if root.data==x:
        return 'Found'
    if root.data>x:
        return BST(root.left,x)
    else:
        return BST(root.right,x)

def print_bw_k1_k2(root,k1,k2):
    if root is None:
        return
    if root.data>k2:
        print_bw_k1_k2(root.left,k1,k2)
    elif root.data<k1:
        print_bw_k1_k2(root.right,k1,k2)
    else:
        print(root.data)
        print_bw_k1_k2(root.left,k1,k2)
        print_bw_k1_k2(root.right,k1,k2)




def level_wise_input():
    print("Enter the root: ")
    root_data=int(input())
    q=queue.Queue()
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print("Enter the left child for the node ",current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node 
            q.put(left_node)

        print("Enter the right child for the node",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root

root=level_wise_input()
print("Enter the element to find: ")
ele=int(input())
node=BST(root,ele)
if node=='Found':
    
    print('Element is present in the tree.')
else:
    print("Element is not their in the tree.")

print_bw_k1_k2(root,1,4)
# Out:
# Enter the root:
# Enter the left child for the node  4
# Enter the right child for the node 4
# Enter the left child for the node  2
# Enter the right child for the node 2
# Enter the left child for the node  6
# Enter the right child for the node 6
# Enter the left child for the node  1
# Enter the right child for the node 1
# Enter the left child for the node  3
# Enter the right child for the node 3
# Enter the element to find:
# Element is present in the tree.
# 4
# 2
# 1
# 3

# %%
def construct_BST(arr):
    if len(arr)==0 :
        return None

    root_data=arr[len(arr)//2]
    root=Binary_tree_node(root_data)

    root.left=construct_BST(arr[:len(arr)//2])
    root.right=construct_BST(arr[(len(arr)//2)+1:])
    return root

def print_tee_detailed(root):
    if root is None:
        return
    print(root.data,end=': ')
    if root.left!=None:
        print('L',root.left.data,end=', ')
    if root.right!=None:
        print('R',root.right.data)
    print()
    print_tee_detailed(root.left)
    print()
    print_tee_detailed(root.right)

arr=[1,2,3,4,5,6,7,8,9]
root=construct_BST(arr)
print_tee_detailed(root)
# Out:
# 5: L 3, R 8
#
# 3: L 2, R 4
#
# 2: L 1,
# 1:
#
#
#
# 4:
#
#
# 8: L 7, R 9
#
# 7: L 6,
# 6:
#
#
#
# 9:

# %%
def min_tree(root):
    if root  is None:
        return 1000000
    left_min=min_tree(root.left)
    right_min=min_tree(root.right)
    return min(left_min,right_min,root.data)

def max_tree(root):
    if root is None:
        return -1000000
    left_max=max_tree(root.left)
    right_max=max_tree(root.right)
    return max(left_max,right_max,root.data)

def is_bst(root):
    if root is None:
        return True
    left_max=max_tree(root.left)
    right_min=min_tree(root.right)

    if root.data<left_max or root.data>right_min:
        return False
    is_left_bst=is_bst(root.left)
    is_right_bst=is_bst(root.right)
    return is_left_bst and is_right_bst

def level_wise_input():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
    

root=level_wise_input()
print(is_bst(root))
# Out:
# Enter the root:
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  2
# Enter the right child for  2
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  1
# Enter the right child for  1
# Enter the left child for  3
# Enter the right child for  3
# True

# %%
def is_bst_2(root):
    if root is None:
        return 1000000,-1000000,True
    left_min,left_max,is_left_bst=is_bst_2(root.left)
    right_min,right_max,is_right_bst=is_bst_2(root.right)

    overall_min=min(left_min,right_min,root.data)
    overall_max=max(left_max,right_max,root.data)
    is_tree_bst=True
    if root.data<=left_max or root.data>=right_min:
        is_tree_bst=False

    if not is_left_bst or not is_right_bst:
        is_right_bst =False
    return (overall_min,overall_max,is_tree_bst)

def level_wise_input():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
    

root=level_wise_input()
print(is_bst_2(root))
# Out:
# Enter the root:
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  2
# Enter the right child for  2
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  1
# Enter the right child for  1
# Enter the left child for  3
# Enter the right child for  3
# (1, 6, True)

# %%
import queue
def is_bst_3(root,min_range,max_range):
    if root is None:
        return True
    if root.data<min_range or root.data>max_range:
        return False
    is_left_within_range=is_bst_3(root.left,min_range,root.data-1)
    is_right_whtihin_range=is_bst_3(root.right,root.data,max_range)
    return is_left_within_range and is_right_whtihin_range
    
def level_wise_input():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
    

root=level_wise_input()
print(is_bst_3(root,-1000000,1000000))
# Out:
# Enter the root:
# Enter the left child for  84
# Enter the right child for  84
# Enter the left child for  41
# Enter the right child for  41
# Enter the left child for  96
# Enter the right child for  96
# Enter the left child for  24
# Enter the right child for  24
# Enter the left child for  50
# Enter the right child for  50
# Enter the left child for  98
# Enter the right child for  98
# Enter the left child for  13
# Enter the right child for  13
# Enter the left child for  37
# Enter the right child for  37
# True

# %%
def node_to_root_path(root,node_data):
    if root is None:
        return None
    
    if root.data==node_data:
        l=list()
        l.append(node_data)
        return l
    
    left_op=node_to_root_path(root.left,node_data)

    if left_op !=None:
        left_op.append(root.data)
        return left_op
    
    right_op=node_to_root_path(root.right,node_data)

    if right_op!=None:
        right_op.append(root.data)
        return right_op
    
    return None

def level_wise_input():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
    

root=level_wise_input()
print(node_to_root_path(root,8))
# Out:
# Enter the root:
# Enter the left child for  1
# Enter the right child for  1
# Enter the left child for  2
# Enter the right child for  2
# Enter the left child for  3
# Enter the right child for  3
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  5
# Enter the right child for  5
# Enter the left child for  9
# Enter the right child for  9
# Enter the left child for  7
# Enter the right child for  7
# Enter the left child for  8
# Enter the right child for  8
# [8, 5, 6, 3, 1]

# %%
class BST:
    def __init__(self):
        self.root=None
        self.numNode=0
    def is_present_helper(self,root,data):
        
        if root==None:
            return False
        
        if root.data==data:
            return True
        
        # if data is smalles then root.data
        if root.data>data:
            return self.is_present_helper(root.left,data)
        else:
            return self.is_present_helper(root.right,data)

    def is_present(self,root,data):
        return self.is_present_helper(root,data)

root=level_wise_input()
print("Enter the element you want to seach")
data=int(input())
b=BST()
print(b.is_present(root,data))
# Out:
# Enter the root:
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  2
# Enter the right child for  2
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  1
# Enter the right child for  1
# Enter the left child for  3
# Enter the right child for  3
# Enter the element you want to seach
# False

# %%
class BST:
    def __init__(self):
        self.root=None
        self.numNodes=0

    def is_present_helper(self,root,data):
        if root is None:
            return False
        if root.data==data:
            return True
        if root.data>data:
            return self.is_present_helper(root.left,data)
        else:
            return self.is_present_helper(root.right,data)

    def is_present(self,root,data):
        return self.is_present_helper(root,data)

    def print_tree_helper(self,root):
        if root is None:
            return 
        
        print(root.data,end=' ')
        if root.left is not None:
            print('L ',root.left.data,end=',')
        if root.right!=None:
            print('R ',root.right.data)
        print()
        self.print_tree_helper(root.left)
        print()
        self.print_tree_helper(root.right)

    def print_tree(self,root):
        return self.print_tree_helper(root)

root=level_wise_input()
print("Enter the element you want to seach")
data=int(input())
b=BST()
print(b.is_present(root,data))
b.print_tree(root)
# Out:
# Enter the root:
# Enter the left child for  4
# Enter the right child for  4
# Enter the left child for  2
# Enter the right child for  2
# Enter the left child for  6
# Enter the right child for  6
# Enter the left child for  1
# Enter the right child for  1
# Enter the left child for  3
# Enter the right child for  3
# Enter the element you want to seach
# True
# 4 L  2,R  6
#
# 2 L  1,R  3
#
# 1
#
#
# 3
#
#
# 6

# %%
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

class BST:
    def __init__(self):
        self.root=None
        self.count=0
    def insertion_helper(self,root,data):
        if root==None:
            node=Binary_tree_node(data)
            return node

        if root.data>data:
            root.left=self.insertion_helper(root.left,data)
            return root
        else:
            root.right=self.insertion_helper(root.right,data)
            return root

    def insertion(self,root,data):
        return self.insertion_helper(root,data)

    def print_tree_helper(self,root):
        if root is None:
            return
        print(root.data,end=' ')
        if root.left !=None:
            print('L ',root.left.data,end=',')
        if root.right!=None:
            print('R ',root.right.data)
        print()
        self.print_tree_helper(root.left)
        print()
        self.print_tree_helper(root.right)

        
    def print_tree(self,root):
        return self.print_tree_helper(root)


root=level_wise_input()
b=BST()
b.print_tree(root)
print('Enter the node want to insert into the tree: ')
data=int(input())
new_root=b.insertion(root,data)
b.print_tree(new_root)
# Out:
# Enter the root:
# Enter the left child for  84
# Enter the right child for  84
# Enter the left child for  41
# Enter the right child for  41
# Enter the left child for  96
# Enter the right child for  96
# Enter the left child for  24
# Enter the right child for  24
# Enter the left child for  50
# Enter the right child for  50
# Enter the left child for  98
# Enter the right child for  98
# Enter the left child for  13
# Enter the right child for  13
# Enter the left child for  37
# Enter the right child for  37
# 84 L  41,R  96
#
# 41 L  24,R  50
#
# 24 L  13,R  37
#
# 13
#
#
# 37
#
#
# 50
#
#
# 96 R  98
#
#
# 98
#
# Enter the node want to insert into the tree:
# 84 L  41,R  96
#
# 41 L  24,R  50
#
# 24 L  13,R  37
#
# 13
#
#
# 37
#
#
# 50 L  47,
# 47
#
#
#
# 96 R  98
#
#
# 98

# %%
class BST:
    def __init__(self):
        self.root=None
        self.count=0

    def delete_helper(self,root,data):
        if root is None:
            return False,None
        if root.data>data:
            deleted,new_left=self.delete_helper(root.left,data)
            root.left=new_left
            return deleted,root
        if root.data<data:
            deleted,new_right=self.delete_helper(root.right,data)
            root.right=new_left
            return deleted,root
        #  leaf node:

        if root.left==None and root.right==None:
            return True,None
        # one child
         
        if root.left ==None:
            return True,root.right
        if root.right==None:
            return True,root.left

        # two child :

# %%
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def BST(root,x):
    if root is None:
        return 'Not Found'
    if root.data==x:
        return 'Element found'
    if root.data>x:
        return BST(root.left,x)
    else:
        return BST(root.right,x)

    


def taking_input_level_wise():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print("Enter the left child for the node ",current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for the node ",current_node.data)
        right_child=int(input())
        if right_child !=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)

    return root

root=taking_input_level_wise()
print('Enter the element to search in the tree: ')
ele=int(input())
node=BST(root,ele)
print(node)
# Out:
# Enter the root:
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  6
# Enter the right child for the node  6
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  3
# Enter the right child for the node  3
# Enter the element to search in the tree:
# Not Found

# %%
class BST:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def print_bw_k1_k2(root,k1,k2):
    if root is None:
        return 
    if root.data>k2:
        print_bw_k1_k2(root.left,k1,k2)
    elif root.data<k1:
        print_bw_k1_k2(root.right,k1,k2)
    else:
        print(root.data)
        print_bw_k1_k2(root.left,k1,k2)
        print_bw_k1_k2(root.right,k1,k2)
#    return root

def taking_input_level_wise():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)
    
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print("Enter the left child for the node ",current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for the node ",current_node.data)
        right_child=int(input())
        if right_child !=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)

    return root

root=taking_input_level_wise()
print("Enter the range in between search is needed: ")
k1,k2=list(map(int,input().split()))
print_bw_k1_k2(root,k1,k2)
# Out:
# Enter the root:
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  6
# Enter the right child for the node  6
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  3
# Enter the right child for the node  3
# Enter the range in between search is needed:
# 4
# 2
# 1
# 3
# 6

# %%
def construct_BST(arr):
    if len(arr)==0:
        return None
    root_data=arr[len(arr)//2]
    root=Binary_tree_node(root_data)
    root.left=construct_BST(arr[:len(arr)//2])
    root.right=construct_BST(arr[len(arr)//2+1:])
    return root


def print_tree_detailed(root):
    if root is None:
        return
    print(root.data,end=' ')
    if root.left!=None:
        print('L ',root.left.data,end=',')
    if root.right!=None:
        print('R ',root.right.data)
    print()
    print_tee_detailed(root.left)
    print()
    print_tee_detailed(root.right)


    
arr=list(map(int,input().split()))
root=construct_BST(arr)
print_tree_detailed(root)
# Out:
# 5 L  3,R  8
#
# 3: L 2, R 4
#
# 2: L 1,
# 1:
#
#
#
# 4:
#
#
# 8: L 7, R 9
#
# 7: L 6,
# 6:
#
#
#
# 9:

# %%
def minTree(root):
    if root is None:
        return float('inf')
    left_min=minTree(root.left)
    right_min=minTree(root.right)
    return min(left_min,right_min,root.data)

def maxTree(root):
    if root is None:
        return -float('inf')
    left_max=maxTree(root.left)
    right_max=maxTree(root.right)
    return max(left_max,right_max,root.data)



def check_bst(root):
    if root is None:
        return True
    if root.data<maxTree(root.left) or root.data>minTree(root.right):
        return False
    check_bst_left=check_bst(root.left)
    check_bst_right=check_bst(root.right)
    return check_bst_left and check_bst_right

    
def print_tree_detailed(root):
    if root is None:
        return
    print(root.data,end=' ')
    if root.left!=None:
        print('L ',root.left.data,end=',')
    if root.right!=None:
        print('R ',root.right.data)
    print()
    print_tee_detailed(root.left)
    print()
    print_tee_detailed(root.right)
def taking_input_level_wise():
    print('Enter the root node: ')
    root_data=int(input())
    if root_data!=-1:
        root=Binary_tree_node(root_data)

    q=queue.Queue()
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left node for the node ',current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_tree_node(left_child)
            current_node.left=left_node
            q.put(left_node)
        print('Enter the right node for the node',current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_tree_node(right_child)
            current_node.right=right_node
            q.put(right_node)

    return root

root=taking_input_level_wise()
print_tree_detailed(root)
print(check_bst(root))
# Out:
# Enter the root node:
# Enter the left node for the node  4
# Enter the right node for the node 4
# Enter the left node for the node  2
# Enter the right node for the node 2
# Enter the left node for the node  6
# Enter the right node for the node 6
# Enter the left node for the node  4
# Enter the right node for the node 4
# 4 L  2,R  6
#
# 2: L 4,
# 4:
#
#
#
# 6:
#
# False

# %%
def check_bst_2(root):
    if root is None:
        return True,float('inf'),-float('inf')
    is_left_bst,left_min,left_max=check_bst_2(root.left)
    is_right_bst,right_min,right_max=check_bst_2(root.right)
    overall_min=min(root.data,left_min,right_min)
    overall_max=max(root.data,right_max,left_max)
    istreebst=True
    if root.data>right_min or root.data<left_max:
        istreebst= False
    if not(is_left_bst) or not(is_right_bst):
        istreebst=False
    return (istreebst,overall_min,overall_max)

root=taking_input_level_wise()
print(check_bst_2(root))
# Out:
# Enter the root node:
# Enter the left node for the node  4
# Enter the right node for the node 4
# Enter the left node for the node  2
# Enter the right node for the node 2
# Enter the left node for the node  1
# Enter the right node for the node 1
# (False, 1, 4)

# %%
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def check_bst_3(root,minrange,maxrange):
    if root is None:
        return True
    if root.data<minrange or root.data>maxrange:
        return False

    is_left_within_range=check_bst_3(root.left,minrange,root.data)
    is_right_within_range=check_bst_3(root.right,root.data,maxrange)
    return is_left_within_range and is_right_within_range

root=taking_input_level_wise()
print(check_bst_3(root,-1000000,1000000))
# Out:
# Enter the root node:
# Enter the left node for the node  4
# Enter the right node for the node 4
# Enter the left node for the node  2
# Enter the right node for the node 2
# Enter the left node for the node  6
# Enter the right node for the node 6
# Enter the left node for the node  1
# Enter the right node for the node 1
# Enter the left node for the node  7
# Enter the right node for the node 7
# False

# %%
def node_to_root_path(root,node):
    if root is None:
        return None
    if root.data==node:
        l=list()
        l.append(node)
        return l
    left_op=node_to_root_path(root.left,node)
    if left_op!=None:
        left_op.append(root.data)
        return left_op
    right_op=node_to_root_path(root.right,node)
    if right_op!=None:
        right_op.append(root.data)
        return right_op
    #return None
root=taking_input_level_wise()
print('Enter the node')
node=int(input())
print(node_to_root_path(root,node))
# Out:
# Enter the root node:
# Enter the left node for the node  4
# Enter the right node for the node 4
# Enter the left node for the node  2
# Enter the right node for the node 2
# Enter the left node for the node  6
# Enter the right node for the node 6
# Enter the left node for the node  1
# Enter the right node for the node 1
# Enter the left node for the node  3
# Enter the right node for the node 3
# Enter the node
# None

# %%
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

class BST:
    def __init__(self):
        self.root=None
        self.count=0

    def ispresent(self,root,data):
        if root is None:
            return False
        if root.data==data:
            return True
        if root.data>data:
            return self.ispresent(root.left,data)
        else:
            return self.ispresent(root.right,data)

    def printtree(self,root):
        if root is None:
            return 

        print(root.data,end=': ')
        if root.left!=None:
            print('L: ',root.left.data,end=',')
        if root.right!=None:
            print('R: ',root.right.data)
        print()
        self.printtree(root.left)
        print()
        self.printtree(root.right)

    def taking_input_level_wise(self):
        print("Enter the root node of the tree: ")
        root_data=int(input())
        q=queue.Queue()
        if root_data!=-1:
            root=Binary_tree_node(root_data)
        q.put(root)
        while q.empty()!=True:
            current_node=q.get()
            print('Enter the left child for the node ',current_node.data)
            left_child = int(input())
            if left_child!=-1:
                left_node=Binary_tree_node(left_child)
                current_node.left=left_node
                q.put(left_node)
            print('Enter the right child for the node ',current_node.data)
            right_child =int(input())
            if right_child!=-1:
                right_node=Binary_tree_node(right_child)
                current_node.right=right_node
                q.put(right_node)
        return root

b=BST()
root=b.taking_input_level_wise()
b.printtree(root)
print('Enter the node to search in above tree: ')
node=int(input())
print(b.ispresent(root,node))
# Out:
# Enter the root node of the tree:
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  6
# Enter the right child for the node  6
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  3
# Enter the right child for the node  3
# Enter the left child for the node  5
# Enter the right child for the node  5
# Enter the left child for the node  7
# Enter the right child for the node  7
# 4: L:  2,R:  6
#
# 2: L:  1,R:  3
#
# 1:
#
#
# 3:
#
#
# 6: L:  5,R:  7
#
# 5:
#
#
# 7:
#
# Enter the node to search in above tree:
# False

# %%
class BST:
    def __init__(self):
        self.root=None
        self.count=0

    def insertnode(self,root,data):
        if root is None:
            node=Binary_tree_node(data)
            return node
        
        if root.data>data:
            root.left=self.insertnode(root.left,data)
            return root
        else:
            root.right=self.insertnode(root.right,data)
            return root
    
    def printtree(self,root):
        if root is None:
            return 

        print(root.data,end=': ')
        if root.left!=None:
            print('L: ',root.left.data,end=',')
        if root.right!=None:
            print('R: ',root.right.data)
        print()
        self.printtree(root.left)
        print()
        self.printtree(root.right)

    def taking_input_level_wise(self):
        print("Enter the root node of the tree: ")
        root_data=int(input())
        q=queue.Queue()
        if root_data!=-1:
            root=Binary_tree_node(root_data)
        q.put(root)
        while q.empty()!=True:
            current_node=q.get()
            print('Enter the left child for the node ',current_node.data)
            left_child = int(input())
            if left_child!=-1:
                left_node=Binary_tree_node(left_child)
                current_node.left=left_node
                q.put(left_node)
            print('Enter the right child for the node ',current_node.data)
            right_child =int(input())
            if right_child!=-1:
                right_node=Binary_tree_node(right_child)
                current_node.right=right_node
                q.put(right_node)
        return root
            
b=BST()
root=b.taking_input_level_wise()
b.printtree(root)
print('Print the node need to enter in the above tree: ')
node=int(input())
new_root=b.insertnode(root,node)
b.printtree(new_root)
# Out:
# Enter the root node of the tree:
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  6
# Enter the right child for the node  6
# 4: L:  2,R:  6
#
# 2:
#
#
# 6:
#
# Print the node need to enter in the above tree:
# 4: L:  2,R:  6
#
# 2: L:  1,
# 1:
#
#
#
# 6:

# %%
class BST:
    def __init__(self):
        self.root=None
        self.count=0

    def deleteNode(self,root,key):
        if root is None:
            return root
 
        # If the key to be deleted
        # is smaller than the root's
        # key then it lies in  left subtree
        if key < root.data:
            root.left = self.deleteNode(root.left, key)
    
        # If the kye to be delete
        # is greater than the root's key
        # then it lies in right subtree
        elif(key > root.data):
            root.right = self.deleteNode(root.right, key)
    
        # If key is same as root's key, then this is the node
        # to be deleted
        else:
            if root.left==None and root.right==None :
                return None
    
            # Node with only one child or no child
            if root.left is None:
                temp = root.right
                root = None
                return temp
    
            elif root.right is None:
                temp = root.left
                root = None
                return temp
    
            # Node with two children:
            # Get the inorder successor
            # (smallest in the right subtree)
            temp = self.minm(root.right)
    
            # Copy the inorder successor's
            # content to this node
            root.data = temp
    
            # Delete the inorder successor
            root.right = self.deleteNode(root.right, temp)
    
        return root

    def minm(self,root):
        if root is None:
            return float('inf')
            left_min=self.minm(root.left)
            right_min=self.minm(root.right)
            return min(left_min,right_min,root.data)

    def printtree(self,root):
        if root is None:
            return 

        print(root.data,end=': ')
        if root.left!=None:
            print('L: ',root.left.data,end=',')
        if root.right!=None:
            print('R: ',root.right.data)
        print()
        self.printtree(root.left)
        print()
        self.printtree(root.right)

    def taking_input_level_wise(self):
        print("Enter the root node of the tree: ")
        root_data=int(input())
        q=queue.Queue()
        if root_data!=-1:
            root=Binary_tree_node(root_data)
        q.put(root)
        while q.empty()!=True:
            current_node=q.get()
            print('Enter the left child for the node ',current_node.data)
            left_child = int(input())
            if left_child!=-1:
                left_node=Binary_tree_node(left_child)
                current_node.left=left_node
                q.put(left_node)
            print('Enter the right child for the node ',current_node.data)
            right_child =int(input())
            if right_child!=-1:
                right_node=Binary_tree_node(right_child)
                current_node.right=right_node
                q.put(right_node)
        return root
            
b=BST()
root=b.taking_input_level_wise()
b.printtree(root)
print('Print the node need to delete in the above tree: ')
node=int(input())
new_root=b.deleteNode(root,node)
b.printtree(new_root)
# Out:
# Enter the root node of the tree:
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  6
# Enter the right child for the node  6
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  3
# Enter the right child for the node  3
# 4: L:  2,R:  6
#
# 2: L:  1,R:  3
#
# 1:
#
#
# 3:
#
#
# 6:
#
# Print the node need to delete in the above tree:
# 4: L:  2,
# 2: L:  1,R:  3
#
# 1:
#
#
# 3:

# %%
class BinaryTreeNode:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
class BST:
    def __init__(self):
        self.root=None
        self.numNodes=0
    def printTreeHelper(self,root):
        if root==None:
            return
        print(root.data,end=":")
        if root.left!=None:
            print("L",root.left.data,end=",")
        if root.right!=None:
            print("R",root.right.data,end="")
        print()
        self.printTreeHelper(root.left)
        self.printTreeHelper(root.right)
        
    def printTree(self):
        self.printTreeHelper(self.root)
    def isPresentHelper(self,root,data):
        if root==None:
            return False
        if root.data==data:
            return True
        if root.data>data:
            #call on left
            return self.isPresentHelper(root.left,data)
        else:
            #Call on right
            return self.isPresentHelper(root.right,data)
    def isPresent(self,data):
        return self.isPresentHelper(self.root,data)
    def insertHelper(self,root,data):
        if root==None:
            node=BinaryTreeNode(data)
            return node
        if root.data>data:
            root.left=self.insertHelper(root.left,data)
            return root
        else:
            root.right=self.insertHelper(root.right,data)
            return root
    def insert(self,data):
        self.numNodes+=1
        self.root=self.insertHelper(self.root,data)
    def min(self,root):
        if root==None:
            return 10000
        if root.left==None:
            return root.data
        return self.min(root.left)
    def deleteDataHelper(self,root,data):
        if root==None:
            return False, None
        if root.data<data:
            deleted,newRightNode=self.deleteDataHelper(root.right,data)
            root.right=newRightNode
            return deleted,root
        if root.data>data:
            deleted,newLeftNode=self.deleteDataHelper(root.left,data)
            root.left=newLeftNode
            return deleted,root
        #root is leaf
        if root.left==None and root.right==None:
            return True, None
        # root has one child
        if root.left==None:
            return True,root.right
        if root.right==None:
            return True,root.left
        #root has 2 children
        replacement=self.min(root.right)
        root.data=replacement
        deleted,newRightNode=self.deleteDataHelper(root.right,replacement)
        root.right=newRightNode
        return True,root
    def deleteData(self,data):
        deleted,newRoot=self.deleteDataHelper(self.root,data)
        if deleted:
            self.numNodes-=1
        self.root=newRoot
        return deleted
        
    def count(self):
        return self.numNodes

b=BST()
b.insert(10)
b.insert(5)
b.insert(12)

print(b.isPresent(10))
print(b.isPresent(7))
print(b.deleteData(4))
print(b.deleteData(10))
print(b.count())
b.printTree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.printTree()
print(b.count())

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.printTree()
print(b.count())
b.deleteData(8)
b.printTree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.printTree()
print(b.count())
b.deleteData(8)
b.printTree()
b.deleteData(5)
b.printTree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.printTree()
print(b.count())
b.deleteData(10)
b.printTree()
# Out:
# True
# False
# False
# True
# 2
# 12:L 5,
# 5:
# 10:L 5,R 12
# 5:R 7
# 7:L 6,R 8
# 6:
# 8:
# 12:L 11,R 15
# 11:
# 15:
# 8
# 10:L 5,R 12
# 5:R 7
# 7:L 6,R 8
# 6:
# 8:
# 12:L 11,R 15
# 11:
# 15:
# 8
# 10:L 5,R 12
# 5:R 7
# 7:L 6,
# 6:
# 12:L 11,R 15
# 11:
# 15:
# 10:L 5,R 12
# 5:R 7
# 7:L 6,R 8
# 6:
# 8:
# 12:L 11,R 15
# 11:
# 15:
# 8
# 10:L 5,R 12
# 5:R 7
# 7:L 6,
# 6:
# 12:L 11,R 15
# 11:
# 15:
# 10:L 7,R 12
# 7:L 6,
# 6:
# 12:L 11,R 15
# 11:
# 15:
# 10:L 5,R 12
# 5:R 7
# 7:L 6,R 8
# 6:
# 8:
# 12:L 11,R 15
# 11:
# 15:
# 8
# 11:L 5,R 12
# 5:R 7
# 7:L 6,R 8
# 6:
# 8:
# 12:R 15
# 15:

# %%
#User function Template for python3

'''
# Node Class:
class Node:
    def _init_(self,val):
        self.data = val
        self.left = None
        self.right = None
        
        '''
        
def helper(root,s):
    if root:
    
    
        if root.left!=None and root.left.left==None and root.left.right==None:
            s+=root.left.data
            #return s
        helper(root.left,s)
        helper(root.right,s)
        print(s)
    return s
def leftLeavesSum(root_node):
    # Complete this function
    s=0
    s=helper(root,s)
    return s
   
    

#{ 
#  Driver Code Starts
#Initial Template for Python 3

from collections import deque
# Tree Node
class Node:
    def __init__(self, val):
        self.right = None
        self.data = val
        self.left = None

# Function to Build Tree   
def buildTree(s):
    #Corner Case
    if(len(s)==0 or s[0]=="N"):           
        return None
        
    # Creating list of strings from input 
    # string after spliting by space
    ip=list(map(str,s.split()))
    
    # Create the root of the tree
    root=Node(int(ip[0]))                     
    size=0
    q=deque()
    
    # Push the root to the queue
    q.append(root)                            
    size=size+1 
    
    # Starting from the second element
    i=1                                       
    while(size>0 and i<len(ip)):
        # Get and remove the front of the queue
        currNode=q[0]
        q.popleft()
        size=size-1
        
        # Get the current node's value from the string
        currVal=ip[i]
        
        # If the left child is not null
        if(currVal!="N"):
            
            # Create the left child for the current node
            currNode.left=Node(int(currVal))
            
            # Push it to the queue
            q.append(currNode.left)
            size=size+1
        # For the right child
        i=i+1
        if(i>=len(ip)):
            break
        currVal=ip[i]
        
        # If the right child is not null
        if(currVal!="N"):
            
            # Create the right child for the current node
            currNode.right=Node(int(currVal))
            
            # Push it to the queue
            q.append(currNode.right)
            size=size+1
        i=i+1
    return root
    
    
if __name__=="__main__":
    t=int(input())
    for _ in range(0,t):
        s=input()
        root=buildTree(s)
        print(leftLeavesSum(root))

# } Driver Code Ends
# Out:
# 2
# 9
# 9
# 2
# 2
# 2
# 2
# 2

# %% [markdown]
# # revison 1/2/22

# %%
import queue
class Binary_search_tree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
def BST(root,x):
    if root is None:
        return 'Not Found'
    if root.data==x:
        return "FOUND"
    if root.data>x:
        return BST(root.left,x)
    else:
        return  BST(root.right,x)
    return "Not Found"

def take_input_level_wise():
    print("Enter the root node: ")
    root_data=int(input())
    if root_data==-1:
        return None
    else:
        root=Binary_search_tree(root_data)

    q=queue.Queue()
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print("Enter the left node for the node ",current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right node for the node ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_search_tree(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root

def print_tree(root):
    if root is None:
        return None
    print(root.data,end=": ")
    if root.left!=None:
        print('L: ',root.left.data,end=', ')
    if root.right!=None:
        print('R: ',root.right.data)
    print()
    print_tree(root.left)
    print()
    print_tree(root.right)

root=take_input_level_wise()
print("Enter the node want to search in the BST: ")
x=(int(input()))
node=(BST(root,x))
print(node)
print_tree(root)
# Out:
# Enter the root node:
# Enter the left node for the node  4
# Enter the right node for the node  4
# Enter the left node for the node  2
# Enter the right node for the node  2
# Enter the left node for the node  6
# Enter the right node for the node  6
# Enter the left node for the node  1
# Enter the right node for the node  1
# Enter the left node for the node  3
# Enter the right node for the node  3
# Enter the node want to search in the BST:
# FOUND
# 4: L:  2, R:  6
#
# 2: L:  1, R:  3
#
# 1:
#
#
# 3:
#
#
# 6:

# %%
# lets search in BST:

import queue
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
def BST(root,x):
        if root is None:
            return -1
        if root.data==x:
            return "FOUND"
        if root.data>x:
            return BST(root.left,x)
        else:
            return  BST(root.right,x)
def level_wise_input():
        q=queue.Queue()
        print("Enter root")
        root_data=int(input())
        if root_data!=-1:
            root=Binary_tree_node(root_data)
        else:
            return None
        q.put(root)
        while q.empty()!=True:
            current_node=q.get()
            print("Enter the left child of node",current_node.data)
            left_child=int(input())
            if left_child!=-1:
                left_node=Binary_tree_node(left_child)
                current_node.left=left_node
                q.put(left_node)
            
            print("Enter the right child of node",current_node.data)
            right_child=int(input())
            if right_child!=-1:
                right_node=Binary_tree_node(right_child)
                current_node.right=right_node
                q.put(right_node)
        return root
root=level_wise_input()
print("Enter the node want to search")
x=int(input())
node=BST(root,x)
if node=="FOUND":
    print("Element found")
else:
    print("Element not found")
# Out:
# Enter root
# Enter the left child of node 4
# Enter the right child of node 4
# Enter the left child of node 2
# Enter the right child of node 2
# Enter the left child of node 6
# Enter the right child of node 6
# Enter the left child of node 1
# Enter the right child of node 1
# Enter the left child of node 3
# Enter the right child of node 3
# Enter the node want to search
# Element not found

# %%
class Binary_search_tree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
def print_tree_bw_k1_k2(root,k1,k2):
    if root is None:
        return 
    if root.data>k2:
        print_tree_bw_k1_k2(root.left,k1,k2)
    elif root.data<k1:
        print_tree_bw_k1_k2(root.right,k1,k2)
    else:
        print(root.data)
        print_tree_bw_k1_k2(root.left,k1,k2)
        print_tree_bw_k1_k2(root.right,k1,k2)

def take_input_level_wise():
    print("Enter the root data: ")
    root_data=int(input())
    if root_data==-1:
        return None
    else:
        root=Binary_search_tree(root_data)
    q=queue.Queue()
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print("Enter the left child for node ",current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for node ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_search_tree(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root

root=take_input_level_wise()
print("Enter the range in space separated form: ")
k1,k2=list(map(int,input().split()))
print_tree_bw_k1_k2(root,k1,k2)
# Out:
# Enter the root data:
# Enter the left child for node  4
# Enter the right child for node  4
# Enter the left child for node  2
# Enter the right child for node  2
# Enter the left child for node  6
# Enter the right child for node  6
# Enter the left child for node  1
# Enter the right child for node  1
# Enter the left child for node  3
# Enter the right child for node  3
# Enter the range in space separated form:
# 4
# 2
# 1
# 3
# 6

# %%
def construct_bst(arr):
    if len(arr)==0:
        return None
    root=arr[len(arr)//2]
    root_node=Binary_search_tree(root)
    root_node.left=construct_bst(arr[:len(arr)//2])
    root_node.right=construct_bst(arr[len(arr)//2+1:])
    return root_node
def print_tree_detailed(root):
    if root is None:
        return None
    print(root.data,end=": ")
    if root.left !=None:
        print('L: ',root.left.data,end=', ')
    if root.right!=None:
        print('R: ',root.right.data)
    print()
    print_tree_detailed(root.left)
    print()
    print_tree_detailed(root.right)
arr=list(map(int,input().split()))
root=construct_bst(arr)
print_tree_detailed(root)
# Out:
# 5: L:  3, R:  8
#
# 3: L:  2, R:  4
#
# 2: L:  1,
# 1:
#
#
#
# 4:
#
#
# 8: L:  7, R:  9
#
# 7: L:  6,
# 6:
#
#
#
# 9:

# %%
def inorder(root,arr):
    if root:
        inorder(root.left,arr)
        arr.append(root.data)
        inorder(root.right,arr)

def isBST(root):
    arr=[]
    inorder(root,arr)
    for i in range(len(arr)-1):
        if arr[i]>arr[i+1]:
            return False
    return True

def take_input_level_wise():
    print("Enter the root node: ")
    root_date=int(input())
    if root_date!=-1:
        root=Binary_search_tree(root_date)
    else:
        return None
    q=queue.Queue()
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print("Enter the left child for the node ",current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for the node ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_search_tree(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root

root=take_input_level_wise()
print(isBST(root))
# Out:
# Enter the root node:
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  3
# Enter the right child for the node  3
# True

# %%
def min_tree(root):
    if root is None:
        return float('inf')
    left_min=min_tree(root.left)
    right_min=min_tree(root.right)
    minm=min(left_min,right_min,root.data)
    return minm
def max_tree(root):
    if root is None:
        return -float('inf')
    left_max=max_tree(root.left)
    right_max=max_tree(root.right)
    maxm=max(left_max,right_max,root.data)
    return maxm

def isBST_2(root):
    if root is None:
        return True
    left_max=max_tree(root.left)
    right_min=min_tree(root.right)
    if root.data<left_max or root.data>right_min:
        return False
    
    is_left_bst=isBST_2(root.left)
    is_right_bst=isBST_2(root.right)
    return is_left_bst and is_right_bst

def take_input_level_wise():
    print("Enter the root node: ")
    root_date=int(input())
    if root_date!=-1:
        root=Binary_search_tree(root_date)
    else:
        return None
    q=queue.Queue()
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print("Enter the left child for the node ",current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for the node ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_search_tree(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root

root=take_input_level_wise()
print(isBST_2(root))
# Out:
# Enter the root node:
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  3
# Enter the right child for the node  3
# False

# %%
def isBST_3(root):
    if root is None:
        return -float('inf'),float('inf'),True
    left_max,left_min,left_bst=isBST_3(root.left)
    right_max,right_min,right_bst=isBST_3(root.right)
    overall_minm=min(left_min,right_min,root.data)
    overall_maxm=max(left_max,right_max,root.data)
    is_tree_bst=True
    if root.data<left_max or root.data>right_min:
        is_tree_bst=False
    if not(left_bst) or not(right_bst):
        is_tree_bst=False
    return (overall_maxm,overall_minm,is_tree_bst)

def take_input_level_wise():
    q=queue.Queue()
    print("Enter the root node: ")
    root_data=int(input())
    if root_data==-1:
        return None
    else:
        root=Binary_search_tree(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for the node ',current_node.data)
        left_child =int(input())
        if left_child !=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for the node ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_search_tree(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root

root=take_input_level_wise()
print(isBST_3(root))
# Out:
# Enter the root node:
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  6
# Enter the right child for the node  6
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  3
# Enter the right child for the node  3
# (6, 1, True)

# %%
def is_bst_helper(root,min_range,max_range):
    if root is None:
        return True
    if root.data<min_range or root.data>max_range:
        return False
    left_bst=is_bst_helper(root.left,min_range,root.data)
    right_bst=is_bst_helper(root.right,root.data,max_range)
    return  left_bst and right_bst
def is_bst_4(root):
    return is_bst_helper(root,-10000000,10000000)

def take_input_level_wise():
    q=queue.Queue()
    print("Enter the root node: ")
    root_data=int(input())
    if root_data==-1:
        return None
    else:
        root=Binary_search_tree(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for the node ',current_node.data)
        left_child =int(input())
        if left_child !=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for the node ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_search_tree(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root

root=take_input_level_wise()
print(is_bst_4(root))
# Out:
# Enter the root node:
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  6
# Enter the right child for the node  6
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  3
# Enter the right child for the node  3
# True

# %%
def root_to_node(root,node):
    if root==None:
        return None
    if root.data==node:
        l=list()
        l.append(root.data)
        return l
    left_path=root_to_node(root.left,node)
    if left_path!=None:
        left_path.append(root.data)
        return left_path
    right_path=root_to_node(root.right,node)
    if right_path is not None:
        right_path.append(root.data)
        return right_path
    return None
def take_input_level_wise():
    q=queue.Queue()
    print("Enter the root node: ")
    root_data=int(input())
    if root_data==-1:
        return None
    else:
        root=Binary_search_tree(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print('Enter the left child for the node ',current_node.data)
        left_child =int(input())
        if left_child !=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for the node ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_search_tree(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root

root=take_input_level_wise()
print("Enter the node for path: ")
node=int(input())
print(root_to_node(root,node))
# Out:
# Enter the root node:
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  3
# Enter the right child for the node  3
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  5
# Enter the right child for the node  5
# Enter the node for path:
# [1]

# %%
class BST:
    def __init__(self):
        self.root=None
        self.count_nodes=0

    def isPresent_helper(self,root,data):
        if root is None:
            return None
        if root.data==data:
            return True
        if root.data<data:
            return self.isPresent_helper(root.right,data)
        else:
            return self.isPresent_helper(root.left,data)
    def isPresent(self,data):
        return self.isPresent_helper(self.root,data)

    def print_tree_helpere(self,root):
        if root is None:
            return 
        print(root.data,end=', ')
        if root.left!=None:
            print('L: ',root.left.data,end=', ')
        if root.right!=None:
            print('R: ',root.right.data)
        print()
        self.print_tree_helpere(root.left)
        print()
        self.print_tree_helpere(root.right)
    def print_tree(self):
        self.print_tree_helpere(self.root)
    

    def insert_tree_helper(self,root,data):
        
        if root is None:
            node=Binary_search_tree(data)
            return node

        if root.data>data:
            root.left=self.insert_tree_helper(root.left,data)
            return root
        else:
            root.right=self.insert_tree_helper(root.right,data)
            return root
    def insert_tree(self,data):
        self.count_nodes+=1
        self.root=self.insert_tree_helper(self.root,data)

        
    def min_tree(self,root):
        if root ==None:
            return float('inf')
        if root.left==None:
            return root.data
        else:
            return self.min_tree(root.left)

    def delete_node_helper(self,root,data):
        if root is None:
            return False,None
        if root.data>data:
            deleted,new_left=self.delete_node_helper(root.left,data)
            root.left=new_left
            return deleted,root
        if root.data>data:
            deleted,new_right=self.delete_node_helper(root.right,data)
            root.right=new_right
            return deleted,root
        
        if root.left==None and root.right==None:
            return True,None
        if root.left==None:
            return True,root.right
        if root.right==None:
            return True,root.left
        replacement= self.min_tree(root.right)
        root.data=replacement
        deleted,new_right=self.delete_node_helper(root.right,replacement)
        root.right=new_right
        return True,root
        
            
            
    def delete_node(self,data):
        deleted,new_root=self.delete_node_helper(self.root,data)
        if deleted:
            self.count_nodes-=1
            return  deleted

    def count(self):
        return self.count_nodes
b=BST()
b.insert_tree(10)
b.insert_tree(5)
b.insert_tree(12)

print(b.isPresent(10))
print(b.isPresent(7))
print(b.delete_node(4))
print(b.delete_node(10))
print(b.count())
b.print_tree()

b=BST()
b.insert_tree(10)
b.insert_tree(5)
b.insert_tree(7)
b.insert_tree(6)
b.insert_tree(8)
b.insert_tree(12)
b.insert_tree(11)
b.insert_tree(15)
b.print_tree()
print(b.count())

b=BST()
b.insert_tree(10)
b.insert_tree(5)
b.insert_tree(7)
b.insert_tree(6)
b.insert_tree(8)
b.insert_tree(12)
b.insert_tree(11)
b.insert_tree(15)
b.print_tree()
print(b.count())
b.delete_node(8)
b.print_tree()

b=BST()
b.insert_tree(10)
b.insert_tree(5)
b.insert_tree(7)
b.insert_tree(6)
b.insert_tree(8)
b.insert_tree(12)
b.insert_tree(11)
b.insert_tree(15)
b.print_tree()
print(b.count())
b.delete_node(8)
b.print_tree()
b.delete_node(5)
b.print_tree()

b=BST()
b.insert_tree(10)
b.insert_tree(5)
b.insert_tree(7)
b.insert_tree(6)
b.insert_tree(8)
b.insert_tree(12)
b.insert_tree(11)
b.insert_tree(15)
b.print_tree()
print(b.count())
b.delete_node(10)
b.print_tree()
# Out:
# True
# None
# None
# True
# 2
# 12, L:  5,
# 5,
#
#
# 10, L:  5, R:  12
#
# 5, R:  7
#
#
# 7, L:  6, R:  8
#
# 6,
#
#
# 8,
#
#
# 12, L:  11, R:  15
#
# 11,
#
#
# 15,
#
# 8
# 10, L:  5, R:  12
#
# 5, R:  7
#
#
# 7, L:  6, R:  8
#
# 6,
#
#
# 8,
#
#
# 12, L:  11, R:  15
#
# 11,
#
#
# 15,
#
# 8
# 10, L:  7, R:  12
#
# 7, L:  6, R:  8
#
# 6,
#
#
# 8,
#
#
# 12, L:  11, R:  15
#
# 11,
#
#
# 15,
#
# 10, L:  5, R:  12
#
# 5, R:  7
#
#
# 7, L:  6, R:  8
#
# 6,
#
#
# 8,
#
#
# 12, L:  11, R:  15
#
# 11,
#
#
# 15,
#
# 8
# 10, L:  7, R:  12
#
# 7, L:  6, R:  8
#
# 6,
#
#
# 8,
#
#
# 12, L:  11, R:  15
#
# 11,
#
#
# 15,
#
# 10, L:  7, R:  12
#
# 7, L:  6, R:  8
#
# 6,
#
#
# 8,
#
#
# 12, L:  11, R:  15
#
# 11,
#
#
# 15,
#
# 10, L:  5, R:  12
#
# 5, R:  7
#
#
# 7, L:  6, R:  8
#
# 6,
#
#
# 8,
#
#
# 12, L:  11, R:  15
#
# 11,
#
#
# 15,
#
# 8
# 11, L:  5, R:  12
#
# 5, R:  7
#
#
# 7, L:  6, R:  8
#
# 6,
#
#
# 8,
#
#
# 12, R:  15
#
#
# 15,

# %%
# lets search in BST:

import queue
class Binary_tree_node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
def BST(root,x):
        if root is None:
            return -1
        if root.data==x:
            return "FOUND"
        if root.data>x:
            return BST(root.left,x)
        else:
            return  BST(root.right,x)
def level_wise_input():
        q=queue.Queue()
        print("Enter root")
        root_data=int(input())
        if root_data!=-1:
            root=Binary_tree_node(root_data)
        else:
            return None
        q.put(root)
        while q.empty()!=True:
            current_node=q.get()
            print("Enter the left child of node",current_node.data)
            left_child=int(input())
            if left_child!=-1:
                left_node=Binary_tree_node(left_child)
                current_node.left=left_node
                q.put(left_node)
            
            print("Enter the right child of node",current_node.data)
            right_child=int(input())
            if right_child!=-1:
                right_node=Binary_tree_node(right_child)
                current_node.right=right_node
                q.put(right_node)
        return root
root=level_wise_input()
print("Enter the node want to search")
x=int(input())
node=BST(root,x)
if node=="FOUND":
    print("Element found")
else:
    print("Element not found")
# Out:
# Enter root
# Enter the left child of node 4
# Enter the right child of node 4
# Enter the left child of node 2
# Enter the right child of node 2
# Enter the left child of node 6
# Enter the right child of node 6
# Enter the left child of node 1
# Enter the right child of node 1
# Enter the left child of node 3
# Enter the right child of node 3
# Enter the node want to search
# Element not found

# %%
class Binary_search_tree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
class BST:
    def __init__(self):
        self.root=None
        self.count_node=0
    
    def print_tree_helper(self,root):
        if root is None:
            return None
        print(root.data,end=': ')
        if root.left!=None:
            print('L: ',root.left.data,end=', ')
        if root.right!=None:
            print('R: ',root.right.data)
        print()
        self.print_tree_helper(root.left)
        print()
        self.print_tree_helper(root.right)
    def print_tree(self):
        self.print_tree_helper(self.root)

    def is_present_helper(self,root,data):
        if root is None:
            return False
        if root.data==data:
            return True
        if root.data>data:
            return self.is_present_helper(root.left,data)
        else:
            return self.is_present_helper(root.right,data)
    def is_present(self,data):
        if root is None:
            return False
        return self.is_present_helper(self.root,data)

    def insert_helper(self,root,data):
        if root is None:
            node=Binary_search_tree(data)
            return node
        if root.data>data:
            root.left=self.insert_helper(root.left,data)
            return root
        else:
            root.right=self.insert_helper(root.right,data)
            return root
    
    def insert(self,data):
        self.count_node+=1
        self.root=self.insert_helper(self.root,data)

    def minm(self,root):
        if root is None:
            return float('inf')
        if root.left==None:
            return root.data
        else:
            return self.minm(root.left)
        
    def delete_helper(self,root,data):
        if root is None:
            return False,None
        if root.data>data:
            deleted,new_left=self.delete_helper(root.left,data)
            root.left=new_left
            return deleted,root
        if root.data<data:
            deleted,new_right=self.delete_helper(root.right,data)
            root.right=new_right
            return deleted,root
        if root.left==None and root.right==None:
            return True,None
        if root.left==None:
            return True,root.right
        if root.right==None:
            return True,root.left
        replacement=self.minm(root.right)
        root.data=replacement
        deleted,new_right=self.delete_helper(root.right,replacement)
        root.right=new_right
        return True,root

    def delete(self,data):
        deleted,new_root=self.delete_helper(self.root,data)
        if deleted:
            self.count_node-=1
            return deleted
    
    def count(self):
        return self.count_node


b=BST()
b.insert(10)
b.insert(5)
b.insert(12)

print(b.is_present(10))
print(b.is_present(7))
print(b.delete(4))
print(b.delete(10))
print(b.count())
b.print_tree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())
b.delete(8)
b.print_tree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())
b.delete(8)
b.print_tree()
b.delete(5)
b.print_tree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())
b.delete(10)
b.print_tree()
# Out:
# True
# False
# None
# True
# 2
# 12: L:  5,
# 5:
#
#
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6, R:  8
#
# 6:
#
#
# 8:
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 8
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6, R:  8
#
# 6:
#
#
# 8:
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 8
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6,
# 6:
#
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6, R:  8
#
# 6:
#
#
# 8:
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 8
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6,
# 6:
#
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 10: L:  7, R:  12
#
# 7: L:  6,
# 6:
#
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6, R:  8
#
# 6:
#
#
# 8:
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 8
# 11: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6, R:  8
#
# 6:
#
#
# 8:
#
#
# 12: R:  15
#
#
# 15:

# %%
import queue
class  Binary_search_tree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def level_wise_ip():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data==-1:
        return None
    root=Binary_search_tree(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print("Enter the left child for the node ",current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for the node ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_search_tree(root_data)
            current_node.right=right_node
            q.put(right_node)
    return root

def BST(root,x):
    if root is None:
        return 'Not Found'
   
    elif root.data==x:
        return 'Found'
    elif root.data>x:
        return BST(root.left,x)
    else:
        return BST(root.right,x)
  
root=level_wise_ip()
print("Enter the node to search")
x=int(input())
print(BST(root,x))
# Out:
# Enter the root:
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the node to search
# Not Found

# %%
import queue
class  Binary_search_tree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def level_wise_ip():
    q=queue.Queue()
    print("Enter the root: ")
    root_data=int(input())
    if root_data==-1:
        return None
    root=Binary_search_tree(root_data)
    q.put(root)
    while q.empty()!=True:
        current_node=q.get()
        print("Enter the left child for the node ",current_node.data)
        left_child=int(input())
        if left_child!=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        print("Enter the right child for the node ",current_node.data)
        right_child=int(input())
        if right_child!=-1:
            right_node=Binary_search_tree(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root

def print_tree(root):
    if root is None :
        return None
    print(root.data,end=': ')
    if root.left !=None:
        print('L ',root.left.data,end=', ')
    if root.right!=None:
        print("R ",root.right.data)
    print()
    print_tree(root.left)
    print()
    print_tree(root.right)
    
def construct_BST(arr):
    if len(arr)==0:
        return None
    root_index=len(arr)//2
    root=Binary_search_tree(arr[root_index])
    root.left=construct_BST(arr[:root_index])
    root.right=construct_BST(arr[root_index+1:])
    return root
  

arr=list(map(int,input().split()))
print_tree(construct_BST(arr))
# Out:
# 5: L  3, R  8
#
# 3: L  2, R  4
#
# 2: L  1,
# 1:
#
#
#
# 4:
#
#
# 8: L  7, R  9
#
# 7: L  6,
# 6:
#
#
#
# 9:

# %%
class Binary_search_tree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
def minTree(root):
    if root==None:
        return float('inf')
    left_min=minTree(root.left)
    right_min=minTree(root.right)
    return min(left_min,right_min,root.data)

def maxTree(root):
    if root ==None:
        return -float('inf')
    left_max=maxTree(root.left)
    right_max=maxTree(root.right)
    return max(root.data,left_max,right_max)

def isBST(root):
    if root is None:
        return True
    left_max=maxTree(root.left)
    right_min=minTree(root.right)
    if left_max>root.data or right_min<root.data:
        return False
    is_left_BST=isBST(root.left)
    is_right_BST=isBST(root.right)
    return is_left_BST and is_right_BST


def isBST2(root):
    if root is None:
        return float('inf'),-float('inf'),True
    left_min,left_max,is_left_bst=isBST2(root.left)
    right_min,right_max,is_right_bst=isBST2(root.right)
    overall_min=min(left_min,right_min,root.data)
    overall_max=max(left_max,right_max,root.data)
    is_tree_bst=True
    if root.data<left_max or root.data>right_min:
        is_tree_bst=False
    if not(is_left_bst) or not(is_right_bst):
        is_tree_bst=False
    return [overall_min,overall_max,is_tree_bst]    


def isBST3(root,min_range,max_range):
    if root is None:
        return True
    if root.data<min_range or root.data>max_range:
        return False
    is_left_bst=isBST3(root.left,min_range,root.data)
    is_right_bst=isBST3(root.right,root.data,max_range)
    return is_left_bst and is_right_bst

    
root=level_wise_ip()
print(isBST(root))
print(isBST2(root))
print(isBST3(root,-10000000,10000000))
# Out:
# Enter the root:
# Enter the left child for the node  4
# Enter the right child for the node  4
# Enter the left child for the node  2
# Enter the right child for the node  2
# Enter the left child for the node  6
# Enter the right child for the node  6
# Enter the left child for the node  1
# Enter the right child for the node  1
# Enter the left child for the node  3
# Enter the right child for the node  3
# True
# [1, 6, True]
# True

# %%
class Binary_search_tree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
def take_input_level_wise(l):
    if len(l)==0 or l[0]==-1:
        return None
    root_data=l[0]
    root=Binary_search_tree(root_data)
    q=queue.Queue()
    q.put(root)
    i=1
    while q.empty()!=True:
        current_node=q.get()
        left_child=l[i]
        i+=1
        if left_child!=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        right_child=l[i]
        i+=1
        if right_child!=-1:
            right_node=Binary_search_tree(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root

def inorder(root,arr):
    if root:
        inorder(root.left,arr)
        arr.append(root.data)
        inorder(root.right,arr)
        
def isBST_best(root):
    arr=[]
    inorder(root,arr)
    print(arr)
    for i in range(len(arr)-1):
        if arr[i]>arr[i+1]:
            return False
    return True    

l=list(map(int,input().split()))
root=take_input_level_wise(l)
isBST_best(root)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# True

# %%
class Binary_search_tree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
        
def take_input_level_wise(l):
    if len(l)==0 or l[0]==-1:
        return None
    root_data=l[0]
    root=Binary_search_tree(root_data)
    q=queue.Queue()
    q.put(root)
    i=1
    while q.empty()!=True:
        current_node=q.get()
        left_child=l[i]
        i+=1
        if left_child!=-1:
            left_node=Binary_search_tree(left_child)
            current_node.left=left_node
            q.put(left_node)
        right_child=l[i]
        i+=1
        if right_child!=-1:
            right_node=Binary_search_tree(right_child)
            current_node.right=right_node
            q.put(right_node)
    return root
        
def node_to_root_path(root,a):
    if root is None:
        return None
    if root.data==a:
        return [a]
    left_op=node_to_root_path(root.left,a)
    if left_op!=None:
        left_op.append(root.data)
        return left_op
    right_op=node_to_root_path(root.right,a)
    if right_op!=None:
        right_op.append(root.data)
        return right_op
        
    return None
l=list(map(int,input().split()))
root=take_input_level_wise(l)
a=int(input())
print(node_to_root_path(root,a))
# Out:
# [6, 4]

# %%
class Binary_search_tree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
class BST:
    def __init__(self):
        self.root=None
        self.no_of_nodes=0
        
    def is_present_helper(self,root,node):
        if root==None:
            return False
        if root.data==node:
            return True
        if root.data<node:
            return self.is_present_helper(root.right,node)
        else:
            return self.is_present_helper(root.left,node)
            
    def is_present(self,node):
        return self.is_present_helper(self.root,node)
        
    def print_tree_helper(self,root):
        if root is None:
            return None
        print(root.data,end=': ')
        if root.left!=None:
            print("L: ",root.left.data,end=', ')
        if root.right!=None:
            print('R ',root.right.data)
        print()
        self.print_tree_helper(root.left)
        print()
        self.print_tree_helper(root.right)

    
    def print_tree(self):
        self.print_tree_helper(self.root)
        
    
    def insert_helper(self,root,data):
        node=Binary_search_tree(data)
        if root is None:
            return node
        
        if root.data>data:
            root.left=self.insert_helper(root.left,data)
            return root
        else:
            root.right=self.insert_helper(root.right,data)
            return root
            
    
    def insert(self,data):
        self.no_of_nodes+=1
        return self.insert_helper(self.root,data)
    
    def minTree(self,root):
        if root is None:
            return float('inf')
        left_min=self.minTree(root.left)
        right_min=self.minTree(root.right)
        return min(left_min,right_min,root.data)
    
    
    def delete_helper(self,root,data):
        if root is None:
            return False,None
        if root.data>data:
            deleted,new_root=self.delete_helper(root.left,data)
            root.left=new_root
            return deleted,root
        if root.data<data:
            deleted,new_root=self.delete_helper(root.right,data)
            root.right=new_root
            return deleted,root
        
        if root.left==None and root.right==None:
            return True,None
        if root.left==None:
            return True,root.right
        if root.right==None:
            return True,root.left
        replacement=self.minTree(root.right)  # min of right side will be new root after deletion of root
        root.data=replacement
        deleted,new_right=self.delete_helper(root.right,replacement)
        root.right=new_right
        return True,root
        
        
    def delete(self,data):
        deleted,new_root=self.delete_helper(self.root,data)
        if deleted:
            self.no_of_nodes-=1
            print(deleted)
            return new_root
        
    def count(self):
        return self.count_node


b=BST()
b.insert(10)
b.insert(5)
b.insert(12)

print(b.is_present(10))
print(b.is_present(7))
print(b.delete(4))
print(b.delete(10))
print(b.count())
b.print_tree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())
b.delete(8)
b.print_tree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())
b.delete(8)
b.print_tree()
b.delete(5)
b.print_tree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())
b.delete(10)
b.print_tree()

# %%
class Binary_search_tree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
class BST:
    def __init__(self):
        self.root=None
        self.count_node=0
    
    def print_tree_helper(self,root):
        if root is None:
            return None
        print(root.data,end=': ')
        if root.left!=None:
            print('L: ',root.left.data,end=', ')
        if root.right!=None:
            print('R: ',root.right.data)
        print()
        self.print_tree_helper(root.left)
        print()
        self.print_tree_helper(root.right)
    def print_tree(self):
        self.print_tree_helper(self.root)

    def is_present_helper(self,root,data):
        if root is None:
            return False
        if root.data==data:
            return True
        if root.data>data:
            return self.is_present_helper(root.left,data)
        else:
            return self.is_present_helper(root.right,data)
    def is_present(self,data):
        if root is None:
            return False
        return self.is_present_helper(self.root,data)

    def insert_helper(self,root,data):
        if root is None:
            node=Binary_search_tree(data)
            return node
        if root.data>data:
            root.left=self.insert_helper(root.left,data)
            return root
        else:
            root.right=self.insert_helper(root.right,data)
            return root
    
    def insert(self,data):
        self.count_node+=1
        self.root=self.insert_helper(self.root,data)

    def minm(self,root):
        if root is None:
            return float('inf')
        if root.left==None:
            return root.data
        else:
            return self.minm(root.left)
        
    def delete_helper(self,root,data):
        if root is None:
            return False,None
        if root.data>data:
            deleted,new_left=self.delete_helper(root.left,data)
            root.left=new_left
            return deleted,root
        if root.data<data:
            deleted,new_right=self.delete_helper(root.right,data)
            root.right=new_right
            return deleted,root
        if root.left==None and root.right==None:
            return True,None
        if root.left==None:
            return True,root.right
        if root.right==None:
            return True,root.left
        replacement=self.minm(root.right)
        root.data=replacement
        deleted,new_right=self.delete_helper(root.right,replacement)
        root.right=new_right
        return True,root

    def delete(self,data):
        deleted,new_root=self.delete_helper(self.root,data)
        if deleted:
            self.count_node-=1
            return deleted
    
    def count(self):
        return self.count_node


b=BST()
b.insert(10)
b.insert(5)
b.insert(12)

print(b.is_present(10))
print(b.is_present(7))
print(b.delete(4))
print(b.delete(10))
print(b.count())
b.print_tree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())
b.delete(8)
b.print_tree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())
b.delete(8)
b.print_tree()
b.delete(5)
b.print_tree()

b=BST()
b.insert(10)
b.insert(5)
b.insert(7)
b.insert(6)
b.insert(8)
b.insert(12)
b.insert(11)
b.insert(15)
b.print_tree()
print(b.count())
b.delete(10)
b.print_tree()
# Out:
# True
# False
# None
# True
# 2
# 12: L:  5,
# 5:
#
#
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6, R:  8
#
# 6:
#
#
# 8:
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 8
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6, R:  8
#
# 6:
#
#
# 8:
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 8
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6,
# 6:
#
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6, R:  8
#
# 6:
#
#
# 8:
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 8
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6,
# 6:
#
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 10: L:  7, R:  12
#
# 7: L:  6,
# 6:
#
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 10: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6, R:  8
#
# 6:
#
#
# 8:
#
#
# 12: L:  11, R:  15
#
# 11:
#
#
# 15:
#
# 8
# 11: L:  5, R:  12
#
# 5: R:  7
#
#
# 7: L:  6, R:  8
#
# 6:
#
#
# 8:
#
#
# 12: R:  15
#
#
# 15:
